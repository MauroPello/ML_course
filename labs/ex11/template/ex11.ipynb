# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from test_utils import test
from typing import NamedTuple, List, Dict, Tuple
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Load the data

# %% [markdown]
# We will be working with the MovieLens dataset, containing 100k movie ratings.
# The goal is to predict the rating of a (movie, user) pair, given other ratings by this user and of this movie.

# %%
data = scipy.io.loadmat("movielens100k.mat")["ratings"]

# %%
data.shape
# Out:
# (1682, 943)

# %%
class Dataset(NamedTuple):
    """Data container with three arrays of the same length:"""

    movies: np.ndarray
    users: np.ndarray
    ratings: np.ndarray


def load_data() -> Dataset:
    """Load ratings and return as Dataset (movies, users, ratings)."""
    data = scipy.io.loadmat("movielens100k.mat")["ratings"]

    # If the returned object is a scipy sparse matrix, read its COO attributes
    import scipy.sparse as sp
    if sp.issparse(data):
        coo = data.tocoo()
        movies = coo.row.astype(int)
        users = coo.col.astype(int)
        ratings = coo.data.astype(float)
    else:
        # Dense case
        movies, users = data.nonzero()
        vals = data[movies, users]
        if hasattr(vals, "A1"):
            ratings = vals.A1
        else:
            ratings = np.asarray(vals).ravel()

    return Dataset(movies, users, ratings)

dataset = load_data()

num_users = np.max(dataset.users) + 1
num_movies = np.max(dataset.movies) + 1

print(
    f"Loaded {len(dataset.ratings)} ratings of {num_users} users for {num_movies} movies."
)
# Out:
# Loaded 100000 ratings of 943 users for 1682 movies.

# %% [markdown]
# # Plot the number of ratings per movie and user
#
# It will be too tricky to make predictions for movies and users for which too few ratings are available.
# Below we will investigate the distribution of how many ratings we have for various users and movies, to evaluate if we need to exclude some users or movies.

# %%
def count_ratings_per_movie(dataset: Dataset) -> Dict[int, int]:
    """Count the number of ratings available per movie

    Inputs:
        dataset: Dataset

    Returns:
        counts: a dictionary form movie id (int) -> count (int)

    >>> count_ratings_per_movie(Dataset(np.array([0, 0, 1]), np.array([1, 2, 1]), np.array([1.0, 2.0, 3.0])))
    {0: 2, 1: 1}
    """
    counts = {}
    for movie in dataset.movies:
        if not movie in counts:
            counts[int(movie)] = 0
        counts[int(movie)] += 1
    return counts


def count_ratings_per_user(dataset: Dataset) -> Dict[int, int]:
    """Count the number of ratings given by a user

    Inputs:
        dataset: Dataset

    Returns:
        counts: a dictionary form user id (int) -> count (int)

    >>> count_ratings_per_user(Dataset(np.array([0, 0, 1]), np.array([1, 2, 2]), np.array([4.0, 1.0, 2.0])))
    {1: 1, 2: 2}
    """
    counts = {}
    for user in dataset.users:
        if not user in counts:
            counts[int(user)] = 0
        counts[int(user)] += 1
    return counts

# %%
test(count_ratings_per_movie)
test(count_ratings_per_user)
# Out:
# ✅ Your `count_ratings_per_movie` passes some basic tests.
# ✅ Your `count_ratings_per_user` passes some basic tests.

# %% [markdown]
# Let's plot the results:

# %%
num_ratings_per_movie = count_ratings_per_movie(dataset)
num_ratings_per_user = count_ratings_per_user(dataset)

fig, axes = plt.subplots(ncols=2, figsize=(10, 2.5))
for ax, ratings, unit in zip(
    axes, (num_ratings_per_movie, num_ratings_per_user), ("movie", "user")
):
    ax.hist(ratings.values())
    ax.set_title(f"# Ratings per {unit} (histogram)")
    ax.set_xlabel("# Ratings")
    ax.set_ylabel("# Occurences")

# %%
print(
    "min # of movies per user = {}, \nmin # of users per movie = {}.".format(
        min(num_ratings_per_user.values()), min(num_ratings_per_movie.values())
    )
)
# Out:
# min # of movies per user = 20,
# min # of users per movie = 1.

# %% [markdown]
# # Remove movies with too few ratings
#
# As is typical for real-life data, those distributions have a very long tail. There are some movies that have only one rating. Predictions for those will be very unreliable, so we want to take them out of the dataset.

# %%
def remove_rare_movies(dataset: Dataset, min_ratings_per_movie=10) -> Dataset:
    """Filter a dataset, and keep only movies with a minimum number of reviews

    Inputs:
        dataset: Dataset
        min_cases: int, the required minimum number

    Returns:
        new dataset: Dataset

    >>> test_dataset = Dataset(np.array([0, 0, 1]), np.array([0, 1, 1]), np.array([1.0, 1.0, 1.0]))
    >>> remove_rare_movies(test_dataset, 2)
    Dataset(movies=array([0, 0]), users=array([0, 1]), ratings=array([1., 1.]))
    """
    num_ratings_per_movie = count_ratings_per_movie(dataset)

    mask = np.zeros([len(dataset.movies)], dtype=bool)
    for i, movie in enumerate(dataset.movies):
        mask[i] = num_ratings_per_movie[movie] >= min_ratings_per_movie

    pruned_dataset = Dataset(
        dataset.movies[mask], dataset.users[mask], dataset.ratings[mask]
    )
    return pruned_dataset

# %%
test(remove_rare_movies)
# Out:
# ✅ Your `remove_rare_movies` passes some basic tests.

# %%
pruned_dataset = remove_rare_movies(dataset)
print(
    f"There are {len(pruned_dataset.ratings)} ratings left after pruning the dataset."
)
# Out:
# There are 97953 ratings left after pruning the dataset.

# %% [markdown]
# # Split the data into a train and test set

# %%
def split_dataset(dataset, p_test=0.1, seed=1):
    """
    Split a dataset randomly into a train and a test part

    Inputs:
        dataset: Dataset
        p_test: float
            propability (0 < p_test < 1) for a data point to go into the test set
        seed: integer

    Returns:
        train_dataset: Dataset
        test_dataset: Dataset

    >>> split_dataset(Dataset(np.array([0, 0]), np.array([1, 0]), np.array([2.0, 1.0])), p_test=0)
    (Dataset(movies=array([0, 0]), users=array([1, 0]), ratings=array([2., 1.])), Dataset(movies=array([], dtype=int64), users=array([], dtype=int64), ratings=array([], dtype=float64)))

    >>> split_dataset(Dataset(np.array([0, 0]), np.array([1, 0]), np.array([2.0, 1.0])), p_test=1)
    (Dataset(movies=array([], dtype=int64), users=array([], dtype=int64), ratings=array([], dtype=float64)), Dataset(movies=array([0, 0]), users=array([1, 0]), ratings=array([2., 1.])))
    """
    # use this generator (https://numpy.org/doc/stable/reference/random/index.html)
    # you should use rng.uniform() once inside this function to match the automatic test case
    rng = np.random.default_rng(seed)

    test_mask = rng.uniform(size=len(dataset.ratings)) < p_test
    train_mask = ~test_mask  # invert the mask

    movies, users, ratings = dataset

    train_data = Dataset(movies[train_mask], users[train_mask], ratings[train_mask])
    test_data = Dataset(movies[test_mask], users[test_mask], ratings[test_mask])

    return train_data, test_data

# %%
test(split_dataset)
# Out:
# ✅ Your `split_dataset` passes some basic tests.

# %%
train_data, test_data = split_dataset(pruned_dataset, p_test=0.1, seed=10)
print("Number of training points:", len(train_data.ratings))
print("Number of test points:", len(test_data.ratings))
# Out:
# Number of training points: 88354
# Number of test points: 9599

# %% [markdown]
# # Visualize the dataset
# So far, our data has been represented by a list of ratings. We will look at how we can interpret these ratings in a matrix (movies x users) and plot it.

# %%
def to_matrix(dataset, num_movies, num_users):
    """
    Construct a dense matrix out of the dataset.

    Input:
        dataset: Dataset

    Output:
        matrix: np.array of floats: (# movies, # users) -> rating (float) or np.NaN if unavailable

    >>> to_matrix(Dataset(np.array([1, 1, 0]), np.array([0, 1, 0]), np.array([1.0, 3.0, 2.5])), 3, 2)
    array([[2.5, nan],
           [1. , 3. ],
           [nan, nan]])
    """
    m = (
        np.zeros([num_movies, num_users]) * np.nan
    )  # We want NaNs for unavailable ratings
    if len(dataset.ratings) > 0:
        m[dataset.movies, dataset.users] = dataset.ratings
    ### HINT: Edit `m` by filling in the available ratings
    return m

# %%
test(to_matrix)
# Out:
# ✅ Your `to_matrix` passes some basic tests.

# %% [markdown]
# Let's plot the train and test dataset

# %%
fig, axes = plt.subplots(ncols=3, figsize=(8, 3))
for ax, label, data in zip(
    axes, ("All data", "Train data", "Test data"), (dataset, train_data, test_data)
):
    im = ax.matshow(to_matrix(data, num_movies, num_users))
    ax.set_title(label)
    ax.set_xlabel("Movie")
    ax.set_ylabel("User")
fig.colorbar(im, label="Rating");

# %% [markdown]
# # Comparing predictors
#
# The goal of recommender systems is to fill in those matrices. In the remainder of this Notebook, we will implement different methods of making those predictions. Let's first develop the tools to compare them.
#
# Our prediction methods will all have the following form:

# %% [markdown]
# As an example, a predictor that recommends the same rating everywhere would look like this:

# %%
class Predictor:
    def __init__(self, train_data: Dataset):
        # This is where you can do any preparation or 'training' if necessary.
        pass

    def __call__(self, test_data: Dataset):
        """
        Make predictions for the users and movies in the test dataset
        (without looking at the ratings).

        Inputs:
            test_data: Dataset (with `n` entries)

        Output:
            predictions: np.array of floats, shape (`n`)
        """
        raise NotImplementedError()

# %% [markdown]
#  You would use a predictor like this as follows:
#
#  ```
#  p = Predictor(train_data)  # this initializes the model. This may include training.
#  predictions = p(test_data)  # this calls `__call__` and makes a prediction.
#  ```

# %%
class GlobalMeanPredictor(Predictor):
    def __init__(self, train_data: Dataset):
        self.mean = train_data.ratings.mean()


    def __call__(self, test_data: Dataset):
        """
        Always predict the mean rating from the training set

        >>> train_data = Dataset(np.array([1, 2, 3, 4]), np.array([1, 2, 3, 4]), np.array([1.0, 2.0, 2.0, 5.0]))
        >>> test_data = Dataset(np.array([1, 2, 3, 4]), np.array([2, 1, 4, 0]), np.array([4.0, 1.0, 1.0, 2.0]))
        >>> mean_predictor = GlobalMeanPredictor(train_data)
        >>> mean_predictor(test_data)
        array([2.5, 2.5, 2.5, 2.5])
        """
        return np.full_like(test_data.ratings, fill_value=self.mean)

# %%
test(GlobalMeanPredictor.__call__)
# Out:
# ✅ Your `__call__` passes some basic tests.

# %% [markdown]
# We can evaluate the predictions using Mean Squared Error:

# %%
def mse(predictions, real_ratings):
    """Compute the mean squared prediction error

    Inputs:
        predictions: np.array of floats, shape (n)
        real_ratings: np.array of floats, shape (n)

    Returns:
        mean squared error: float

    >>> mse(np.array([1., 1.2, 2.]), np.array([2., 1., 1.5]))
    0.43
    >>> mse(np.array([4., 2., 1.]), np.array([4., 3., 1.]))
    0.3333333333333333
    """
    return float(np.mean((predictions - real_ratings) ** 2))

# %%
test(mse)
# Out:
# ✅ Your `mse` passes some basic tests.

# %% [markdown]
# The error for the global mean predictor can now be computed:

# %%
predict_global_mean = GlobalMeanPredictor(train_data)

mse(predict_global_mean(test_data), test_data.ratings)
# Out:
# 1.2472830499388112

# %% [markdown]
# It is always good to include simple baselines like this one in your machine learning experimentation. We now know that we should at least beat an MSE of `1.24` on the test set.

# %% [markdown]
# ## Baselines

# %% [markdown]
# We will now gradually make the baseline predictor more complex, by differentiating between users. The idea is that some users will give higher scores on average than others.

# %% [markdown]
# ### User's mean prediction
#
# Here, to predict the score for a tuple `(movie, user)`, we will return the  average all movie ratings of the `user`.

# %%
class UserMeanPredictor(Predictor):
    def __init__(self, train_data: Dataset):
        unique_users = np.unique(train_data.users)
        self.ratings = np.zeros([np.max(unique_users) + 1]) * np.nan
        for user in unique_users:
            self.ratings[user] = np.mean(train_data.ratings[train_data.users == user])
        # Hint: don't worry about making this part fast.

    def __call__(self, test_data: Dataset):
        """
        >>> train_data = Dataset(np.array([1, 2, 3, 4]), np.array([1, 2, 3, 4]), np.array([1.0, 2.0, 2.0, 5.0]))
        >>> test_data = Dataset(np.array([1, 2, 3, 4]), np.array([2, 1, 4, 0]), np.array([4.0, 1.0, 1.0, 2.0]))
        >>> mean_predictor = GlobalMeanPredictor(train_data)
        >>> mean_predictor(test_data)
        array([2.5, 2.5, 2.5, 2.5])
        """
        return self.ratings[test_data.users]

# %%
test(UserMeanPredictor.__call__)
# Out:
# ✅ Your `__call__` passes some basic tests.

# %% [markdown]
# Is this working better than predicting the global mean?

# %%
predict_user_mean = UserMeanPredictor(train_data)

mse(predict_user_mean(test_data), test_data.ratings)
# Out:
# 1.05863355998289

# %% [markdown]
# Q: Why would always predicting the user's mean be pretty useless in practice?
#
# Q: If you want, you can improve the predictor by falling back to the global mean in case we haven't seen any ratings of a user before (or not enough of them).

# %% [markdown]
# ### Movie's mean prediction
#
# Here, to predict the score for a tuple `(movie, user)`, we will return the  average all movie ratings of the `movie`.
#
# Under what assumption is this a good model?

# %%
class MovieMeanPredictor(Predictor):
    def __init__(self, train_data: Dataset):
        unique_movies = np.unique(train_data.movies)
        self.ratings = np.zeros([np.max(unique_movies) + 1]) * np.nan
        for movie in unique_movies:
            self.ratings[movie] = np.mean(
                train_data.ratings[train_data.movies == movie]
            )
        # Hint: don't worry about making this part fast.

    def __call__(self, test_data: Dataset):
        """
        Predict the mean rating of the movie, irrespective of the user

        >>> train_data = Dataset(np.array([0, 0, 1, 1, 2]), np.array([1, 2, 3, 4, 5]), np.array([4.0, 1.0, 1.0, 2.0, 1.0]))
        >>> test_data = Dataset(np.array([0, 1, 2, 1]), np.array([1, 2, 2, 0]), np.array([1.0, 2.0, 2.5, 5.0]))
        >>> mean_predictor = MovieMeanPredictor(train_data)
        >>> mean_predictor(test_data)
        array([2.5, 1.5, 1. , 1.5])
        """
        return self.ratings[test_data.movies]

# %%
test(MovieMeanPredictor.__call__)
# Out:
# ✅ Your `__call__` passes some basic tests.

# %%
predict_movie_mean = MovieMeanPredictor(train_data)

mse(predict_movie_mean(test_data), test_data.ratings)
# Out:
# 1.013808531170094

# %% [markdown]
# ### Matrix Factorization
#
# With those baselines, we can implement a more realistic recommendation model that using Matrix Factorization.
#
# - To each movie $i$ in the dataset, we will assign a $d$-dimensional trainable ‘representation vector’ $\mathbf{m}_i$.
# - To each user $j$ in the dataset, we will assign a $d$-dimensional trainable ‘representation vector’ $\mathbf{u}_j$.
# - You can summarize those representations in two matrices: $\mathbf{M}$ of size `(#movies, d)`, and $\mathbf{U}$ of size `(#users, d)`.
# - The predicted score we will give for a movie $i$ and a user $j$ will be the dot product $\mathbf{m}_i \cdot \mathbf{u}_j$.
# - You can simultaneously express the predicted scores for all movies and all users as a matrix of size `(#movies, #users)` as the matrix product $\mathbf{M} \mathbf{U}^\top$. This interpretation gives the name to this model.
# - Given a training set $T$ with rating triples `(movie i, user j, rating r)`,
#   we will optimize the mean squared prediction error $\frac{1}{|T|}\sum_{(i, j, r) \in T} (\mathbf{m}_i \cdot \mathbf{u}_j - r)^2$ over the training set.

# %%
class MatrixFactorizationPredictor(Predictor):
    def __init__(self, train_data: Dataset, num_features=20, seed=1):
        # Randomly initialize features for the users and the movies from N(0, 1)

        # use this generator (https://numpy.org/doc/stable/reference/random/index.html)
        # you are expected to use rng.normal() twice in this function to match the tests, once for movies, and then once for users
        rng = np.random.default_rng(seed)

        num_movies = np.max(train_data.movies) + 1
        num_users = np.max(train_data.users) + 1
        self.movie_features = rng.normal(size=[num_movies, num_features])
        self.user_features = rng.normal(size=[num_users, num_features])

        # Normally, you should train the model here, but we will skip this
        # for now, to be able to take it step-by-step.

    def __call__(self, test_data: Dataset):
        """
        Predict the rating of a user/movie pair as the dot-product
        of representation vectors of the user and the movie.

        >>> train_data = Dataset(np.array([0, 0, 1, 1, 2]), np.array([1, 2, 3, 4, 5]), np.array([4.0, 1.0, 1.0, 2.0, 1.0]))
        >>> test_data = Dataset(np.array([0, 1, 2, 1]), np.array([1, 2, 2, 0]), np.array([1.0, 2.0, 2.5, 5.0]))
        >>> mean_predictor = MatrixFactorizationPredictor(train_data)
        >>> mean_predictor(test_data)  # the factorization is not yet optimized here
        array([ 2.62654714, -2.89866225,  0.70909287,  5.29901482])
        """
        user_features = self.user_features[test_data.users]
        movie_features = self.movie_features[test_data.movies]
        return (user_features * movie_features).sum(axis=1)

# %%
test(MatrixFactorizationPredictor.__call__)
# Out:
# ✅ Your `__call__` passes some basic tests.

# %% [markdown]
# Without training, the `MatrixFactorizationPredictor` would not perform so well:

# %%
predict_global_mean = MatrixFactorizationPredictor(train_data)

mse(predict_global_mean(test_data), test_data.ratings)
# Out:
# 33.492564119044054

# %% [markdown]
# ### Optimize the factorization using SGD
#
# One way to optimize the representation vectors for movies and users, is to sample terms from the following loss function:
#
# $$\frac{1}{|T|}\sum_{(i, j, r) \in T} (\mathbf{m}_i \cdot \mathbf{u}_j - r)^2$$
#
# and optimize the sampled $\mathbf{m}_i$ and $\mathbf{u}_j$ using a stochastic gradient descent step.
#
# To improve generalization, we will add L2 regularization (also known as `weight decay`) to this model, both for the movie representations as well as for the user representations. Because those weights are unique for each movie / user, you should also sample those stochastically. If you sample a triple `(i, j, r)`, you should minimize:
#
# $$ (\mathbf{m}_i \cdot \mathbf{u}_j - r)^2 + \lambda_\text{movie} \left\lVert\mathbf{m}_i\right\rVert^2 + \lambda_\text{user} \left\lVert\mathbf{u}_j\right\rVert^2$$
#
# You should start by computing a gradient for this term.

# %%
learning_rate = 0.02
weight_decay_movie = 0.3
weight_decay_user = 0.3

predictor = MatrixFactorizationPredictor(train_data)
rng = np.random.default_rng(0)
for epoch in range(20):
    # Shuffle the dataset
    datapoint_indices = rng.permutation(len(train_data.ratings))
    for point in datapoint_indices:
        movie = train_data.movies[point]
        user = train_data.users[point]
        rating = train_data.ratings[point]

        # Optimize the factorizations in `predictor` using an SGD
        # step based on the datapoint (movie, user, rating).
        user_features = predictor.user_features[user]
        movie_features = predictor.movie_features[movie]
        err = rating - (user_features * movie_features).sum()
        movie_features += learning_rate * (
            err * user_features - weight_decay_movie * movie_features
        )
        user_features += learning_rate * (
            err * movie_features - weight_decay_user * user_features
        )

    learning_rate *= 0.9  # decay the learning rate after each epoch

    print(
        f"Train error after epoch {epoch+1}: {mse(predictor(train_data), train_data.ratings)}"
    )
    print(
        f"Test error after epoch {epoch+1}: {mse(predictor(test_data), test_data.ratings)}"
    )
# Out:
# Train error after epoch 1: 1.1828202273301067
# Test error after epoch 1: 1.8589241570912831
# Train error after epoch 2: 0.9196984250420246
# Test error after epoch 2: 1.252252097103546
# Train error after epoch 3: 0.8968702054954466
# Test error after epoch 3: 1.1150717605161495
# Train error after epoch 4: 0.8814909957512004
# Test error after epoch 4: 1.0465489782417832
# Train error after epoch 5: 0.8932705025715904
# Test error after epoch 5: 1.0267183217910971
# Train error after epoch 6: 0.8883914392235244
# Test error after epoch 6: 1.0092952831382935
# Train error after epoch 7: 0.8907014792529393
# Test error after epoch 7: 0.9954913988709713
# Train error after epoch 8: 0.8843432427613047
# Test error after epoch 8: 0.9717671501043214
# Train error after epoch 9: 0.8977009190964246
# Test error after epoch 9: 0.980458623182079
# Train error after epoch 10: 0.8985028244962339
# Test error after epoch 10: 0.9776489596622311
# Train error after epoch 11: 0.8968866939111572
# Test error after epoch 11: 0.9737767258657799
# Train error after epoch 12: 0.8916063821769988
# Test error after epoch 12: 0.96067597435827
# Train error after epoch 13: 0.8991708465648125
# Test error after epoch 13: 0.966430561659393
# Train error after epoch 14: 0.8946113638543638
# Test error after epoch 14: 0.9596764607171524
# Train error after epoch 15: 0.8998982736824306
# Test error after epoch 15: 0.9614544442677494
# Train error after epoch 16: 0.8980347043415784
# Test error after epoch 16: 0.9596911127091631
# Train error after epoch 17: 0.8965367342261322
# Test error after epoch 17: 0.95718967247935
# Train error after epoch 18: 0.8969648455648147
# Test error after epoch 18: 0.9562259234517876
# Train error after epoch 19: 0.8967847181990276
# Test error after epoch 19: 0.9543667577005126
# Train error after epoch 20: 0.897730396679612
# Test error after epoch 20: 0.9540478786821512

# %% [markdown]
# You should expect the test error to go down below 1.0.
#
# Feel free to play with the weight decay parameters and learning rates to improve these results.

# %% [markdown]
# ### Optimize the factoriziation using Alternating Least Squares
#
# Instead of optimizing the objective
#
# $$\frac{1}{|T|}\sum_{(i, j, r) \in T} (\mathbf{m}_i \cdot \mathbf{u}_j - r)^2 + \lambda_\text{movie} \left\lVert \mathbf{M} \right\rVert^2_\text{F} + \lambda_\text{user} \left\lVert \mathbf{U} \right\rVert^2_\text{F}$$
#
# using SGD by sampling terms, we can also use ‘Alternating Least Squares’. For ALS, we make the observation that, if all users representations $\mathbf{u}_j$ are fixed, optimizing all $\mathbf{m}_i$ is a simple least squares problem. Similarly, if the movie representations $\mathbf{m}_i$ are all fixed, optimizing all $\mathbf{u}_j$ is a simple least squares problem.
#
# What we will do here, is alternate between the following steps:
# - Fix the user representations, and perfectly optimize the movie representations.
# - Fix the movie representations, and perfectly optimize the user representations.

# %%
movie_regularization = 20
user_regularization = 20
max_iterations = 1000
stop_criterion = 1e-4

predictor = MatrixFactorizationPredictor(train_data)
user_features = predictor.user_features
movie_features = predictor.movie_features
rng = np.random.default_rng(0)

prev_train_error = None

for iteration in range(max_iterations):
    # Optimize the user features
    for user in np.unique(train_data.users):
        # Update `user_features[user]` by optimizing the regularized corresponding least squares objective
        mask = train_data.users == user
        user_movies = train_data.movies[mask]
        M = movie_features[user_movies]
        r = train_data.ratings[mask]
        user_features[user] = np.linalg.solve(
            M.T @ M + np.eye(M.shape[1]) * user_regularization, M.T @ r
        )

    # Optimize the movie features using least squares
    for movie in np.unique(train_data.movies):
        # Update `movie_features[movie]` by optimizing the regularized corresponding least squares objective
        mask = train_data.movies == movie
        movie_users = train_data.users[mask]
        M = user_features[movie_users]
        r = train_data.ratings[mask]
        movie_features[movie] = np.linalg.solve(
            M.T @ M + np.eye(M.shape[1]) * movie_regularization, M.T @ r
        )

    train_error = mse(predictor(train_data), train_data.ratings)
    print(f"Train error after step {iteration+1}: {train_error}")
    print(
        f"Test error after step {iteration+1}: {mse(predictor(test_data), test_data.ratings)}"
    )

    # Stop if the training error is not going down more than 'stop_criterion'
    ####################################
    ### ___ Enter your code here ___ ###
    ####################################
# Out:
# Train error after step 1: 4.320768350910532
# Test error after step 1: 5.115121748122441
# Train error after step 2: 1.1894308117241867
# Test error after step 2: 1.3513628812943121
# Train error after step 3: 0.9840145967147838
# Test error after step 3: 1.1163650741660245
# Train error after step 4: 0.8977543547766702
# Test error after step 4: 1.0231617176890087
# Train error after step 5: 0.8575563362008334
# Test error after step 5: 0.9811095470152451
# Train error after step 6: 0.8363511454631072
# Test error after step 6: 0.9598931319754139
# Train error after step 7: 0.8237876972463657
# Test error after step 7: 0.9481697365209227
# Train error after step 8: 0.8156484534419048
# Test error after step 8: 0.9412387698331506
# Train error after step 9: 0.8100407493705151
# Test error after step 9: 0.936921945143188
# Train error after step 10: 0.8060190116223073
# Test error after step 10: 0.9341168852542229
# Train error after step 11: 0.8030577576457877
# Test error after step 11: 0.9322280667389893
# Train error after step 12: 0.8008374712425075
# Test error after step 12: 0.9309170677518046
# Train error after step 13: 0.7991503402274595
# Test error after step 13: 0.9299832286295925
# Train error after step 14: 0.7978547943179018
# Test error after step 14: 0.9293030239037762
# Train error after step 15: 0.7968513239026884
# Test error after step 15: 0.9287977974799969
# Train error after step 16: 0.7960683560776051
# Test error after step 16: 0.9284159179690368
# Train error after step 17: 0.7954534277961464
# Test error after step 17: 0.9281225689406118
# Train error after step 18: 0.794967465643291
# Test error after step 18: 0.9278937190822383
# Train error after step 19: 0.794581001178931
# Test error after step 19: 0.9277124487313586
# Train error after step 20: 0.7942716107090191
# Test error after step 20: 0.9275666439793717
# Train error after step 21: 0.7940221320593202
# Test error after step 21: 0.9274475091838742
# Train error after step 22: 0.7938193827881205
# Test error after step 22: 0.9273485843433208
# Train error after step 23: 0.7936532138830761
# Test error after step 23: 0.9272650823705025
# Train error after step 24: 0.7935157981997998
# Test error after step 24: 0.9271934334960498
# Train error after step 25: 0.7934010897540068
# Test error after step 25: 0.9271309661334327
# Train error after step 26: 0.7933044107201405
# Test error after step 26: 0.927075679042839
# Train error after step 27: 0.7932221352623283
# Test error after step 27: 0.9270260755502205
# Train error after step 28: 0.7931514472332546
# Test error after step 28: 0.926981040700289
# Train error after step 29: 0.7930901543206852
# Test error after step 29: 0.9269397487230179
# Train error after step 30: 0.793036545334654
# Test error after step 30: 0.9269015923891747
# Train error after step 31: 0.7929892804661219
# Test error after step 31: 0.9268661285477588
# Train error after step 32: 0.792947306762148
# Test error after step 32: 0.9268330359044896
# Train error after step 33: 0.792909792917724
# Test error after step 33: 0.9268020822544722
# Train error after step 34: 0.7928760789022661
# Test error after step 34: 0.9267730991419649
# Train error after step 35: 0.7928456370154224
# Test error after step 35: 0.9267459624262754
# Train error after step 36: 0.7928180417796485
# Test error after step 36: 0.9267205775760498
# Train error after step 37: 0.7927929466879112
# Test error after step 37: 0.9266968687533763
# Train error after step 38: 0.7927700662832387
# Test error after step 38: 0.9266747709221788
# Train error after step 39: 0.7927491623911848
# Test error after step 39: 0.9266542243467448
# Train error after step 40: 0.7927300335863398
# Test error after step 40: 0.9266351709511752
# Train error after step 41: 0.7927125071721393
# Test error after step 41: 0.9266175520983142
# Train error after step 42: 0.7926964331060047
# Test error after step 42: 0.9266013074226398
# Train error after step 43: 0.7926816794211962
# Test error after step 43: 0.9265863744183773
# Train error after step 44: 0.7926681287912409
# Test error after step 44: 0.9265726885430864
# Train error after step 45: 0.7926556759583416
# Test error after step 45: 0.9265601836486206
# Train error after step 46: 0.7926442258080197
# Test error after step 46: 0.9265487925959435
# Train error after step 47: 0.7926336919213115
# Test error after step 47: 0.9265384479479425
# Train error after step 48: 0.7926239954753483
# Test error after step 48: 0.9265290826654569
# Train error after step 49: 0.7926150643947474
# Test error after step 49: 0.9265206307567103
# Train error after step 50: 0.7926068326812521
# Test error after step 50: 0.9265130278497778
# Train error after step 51: 0.7925992398686266
# Test error after step 51: 0.9265062116724143
# Train error after step 52: 0.7925922305648664
# Test error after step 52: 0.926500122434173
# Train error after step 53: 0.7925857540551926
# Test error after step 53: 0.9264947031131132
# Train error after step 54: 0.7925797639477515
# Test error after step 54: 0.9264898996541006
# Train error after step 55: 0.792574217850096
# Test error after step 55: 0.9264856610884573
# Train error after step 56: 0.7925690770688617
# Test error after step 56: 0.9264819395859926
# Train error after step 57: 0.7925643063280561
# Test error after step 57: 0.9264786904506697
# Train error after step 58: 0.7925598735033462
# Test error after step 58: 0.926475872070736
# Train error after step 59: 0.7925557493709886
# Test error after step 59: 0.9264734458332342
# Train error after step 60: 0.792551907370779
# Test error after step 60: 0.9264713760117248
# Train error after step 61: 0.7925483233827785
# Test error after step 61: 0.9264696296348397
# Train error after step 62: 0.7925449755177444
# Test error after step 62: 0.9264681763420917
# Train error after step 63: 0.792541843921188
# Test error after step 63: 0.9264669882322327
# Train error after step 64: 0.7925389105909358
# Test error after step 64: 0.926466039708438
# Train error after step 65: 0.7925361592079656
# Test error after step 65: 0.926465307323675
# Train error after step 66: 0.7925335749801656
# Test error after step 66: 0.9264647696288386
# Train error after step 67: 0.792531144498577
# Test error after step 67: 0.9264644070255803
# Train error after step 68: 0.7925288556055797
# Test error after step 68: 0.9264642016251993
# Train error after step 69: 0.7925266972744127
# Test error after step 69: 0.926464137114529
# Train error after step 70: 0.7925246594993723
# Test error after step 70: 0.9264641986293842
# Train error after step 71: 0.7925227331960034
# Test error after step 71: 0.9264643726358639
# Train error after step 72: 0.7925209101105828
# Test error after step 72: 0.9264646468195722
# Train error after step 73: 0.7925191827381972
# Test error after step 73: 0.9264650099826737
# Train error after step 74: 0.7925175442487329
# Test error after step 74: 0.9264654519485583
# Train error after step 75: 0.7925159884201181
# Test error after step 75: 0.9264659634738295
# Train error after step 76: 0.7925145095781868
# Test error after step 76: 0.9264665361672438
# Train error after step 77: 0.7925131025425673
# Test error after step 77: 0.9264671624152235
# Train error after step 78: 0.792511762578041
# Test error after step 78: 0.9264678353135222
# Train error after step 79: 0.7925104853508481
# Test error after step 79: 0.9264685486046316
# Train error after step 80: 0.792509266889461
# Test error after step 80: 0.9264692966205164
# Train error after step 81: 0.7925081035493887
# Test error after step 81: 0.9264700742302753
# Train error after step 82: 0.7925069919816001
# Test error after step 82: 0.926470876792347
# Train error after step 83: 0.7925059291042053
# Test error after step 83: 0.9264717001108901
# Train error after step 84: 0.792504912077056
# Test error after step 84: 0.9264725403959984
# Train error after step 85: 0.7925039382789658
# Test error after step 85: 0.9264733942274217
# Train error after step 86: 0.7925030052872738
# Test error after step 86: 0.9264742585215018
# Train error after step 87: 0.7925021108595068
# Test error after step 87: 0.9264751305010357
# Train error after step 88: 0.7925012529169174
# Test error after step 88: 0.9264760076678162
# Train error after step 89: 0.7925004295297033
# Test error after step 89: 0.9264768877776136
# Train error after step 90: 0.7924996389037237
# Test error after step 90: 0.9264777688173763
# Train error after step 91: 0.7924988793685562
# Test error after step 91: 0.926478648984461
# Train error after step 92: 0.7924981493667543
# Test error after step 92: 0.9264795266677018
# Train error after step 93: 0.792497447444172
# Test error after step 93: 0.9264804004301618
# Train error after step 94: 0.7924967722412491
# Test error after step 94: 0.9264812689934099
# Train error after step 95: 0.7924961224851482
# Test error after step 95: 0.9264821312231901
# Train error after step 96: 0.7924954969826583
# Test error after step 96: 0.9264829861163529
# Train error after step 97: 0.7924948946137829
# Test error after step 97: 0.9264838327889424
# Train error after step 98: 0.792494314325941
# Test error after step 98: 0.9264846704653311
# Train error after step 99: 0.7924937551287138
# Test error after step 99: 0.926485498468309
# Train error after step 100: 0.7924932160890854
# Test error after step 100: 0.9264863162100418
# Train error after step 101: 0.7924926963271235
# Test error after step 101: 0.9264871231838256
# Train error after step 102: 0.7924921950120519
# Test error after step 102: 0.9264879189565557
# Train error after step 103: 0.7924917113586828
# Test error after step 103: 0.9264887031618616
# Train error after step 104: 0.7924912446241631
# Test error after step 104: 0.926489475493837
# Train error after step 105: 0.7924907941050082
# Test error after step 105: 0.926490235701317
# Train error after step 106: 0.7924903591343959
# Test error after step 106: 0.9264909835826568
# Train error after step 107: 0.792489939079689
# Test error after step 107: 0.9264917189809616
# Train error after step 108: 0.7924895333401676
# Test error after step 108: 0.9264924417797359
# Train error after step 109: 0.7924891413449543
# Test error after step 109: 0.926493151898911
# Train error after step 110: 0.7924887625511021
# Test error after step 110: 0.926493849291216
# Train error after step 111: 0.7924883964418447
# Test error after step 111: 0.9264945339388696
# Train error after step 112: 0.7924880425249792
# Test error after step 112: 0.9264952058505582
# Train error after step 113: 0.7924877003313814
# Test error after step 113: 0.9264958650586789
# Train error after step 114: 0.7924873694136297
# Test error after step 114: 0.9264965116168234
# Train error after step 115: 0.7924870493447385
# Test error after step 115: 0.9264971455974843
# Train error after step 116: 0.7924867397169816
# Test error after step 116: 0.9264977670899619
# Train error after step 117: 0.7924864401408064
# Test error after step 117: 0.9264983761984554
# Train error after step 118: 0.7924861502438206
# Test error after step 118: 0.9264989730403249
# Train error after step 119: 0.7924858696698573
# Test error after step 119: 0.9264995577445061
# Train error after step 120: 0.7924855980780996
# Test error after step 120: 0.9265001304500668
# Train error after step 121: 0.7924853351422682
# Test error after step 121: 0.926500691304895
# Train error after step 122: 0.7924850805498634
# Test error after step 122: 0.9265012404645009
# Train error after step 123: 0.7924848340014562
# Test error after step 123: 0.9265017780909327
# Train error after step 124: 0.7924845952100272
# Test error after step 124: 0.9265023043517882
# Train error after step 125: 0.792484363900345
# Test error after step 125: 0.9265028194193179
# Train error after step 126: 0.7924841398083872
# Test error after step 126: 0.9265033234696121
# Train error after step 127: 0.7924839226807943
# Test error after step 127: 0.926503816681864
# Train error after step 128: 0.7924837122743581
# Test error after step 128: 0.9265042992377011
# Train error after step 129: 0.7924835083555418
# Test error after step 129: 0.9265047713205825
# Train error after step 130: 0.7924833107000249
# Test error after step 130: 0.9265052331152533
# Train error after step 131: 0.7924831190922789
# Test error after step 131: 0.9265056848072529
# Train error after step 132: 0.7924829333251633
# Test error after step 132: 0.9265061265824713
# Train error after step 133: 0.7924827531995462
# Test error after step 133: 0.9265065586267518
# Train error after step 134: 0.7924825785239468
# Test error after step 134: 0.9265069811255333
# Train error after step 135: 0.7924824091141941
# Test error after step 135: 0.9265073942635295
# Train error after step 136: 0.7924822447931078
# Test error after step 136: 0.9265077982244453
# Train error after step 137: 0.7924820853901933
# Test error after step 137: 0.9265081931907194
# Train error after step 138: 0.7924819307413531
# Test error after step 138: 0.9265085793433013
# Train error after step 139: 0.7924817806886144
# Test error after step 139: 0.9265089568614492
# Train error after step 140: 0.7924816350798691
# Test error after step 140: 0.9265093259225543
# Train error after step 141: 0.792481493768628
# Test error after step 141: 0.9265096867019872
# Train error after step 142: 0.7924813566137839
# Test error after step 142: 0.9265100393729627
# Train error after step 143: 0.792481223479393
# Test error after step 143: 0.9265103841064233
# Train error after step 144: 0.7924810942344592
# Test error after step 144: 0.9265107210709382
# Train error after step 145: 0.7924809687527335
# Test error after step 145: 0.9265110504326198
# Train error after step 146: 0.7924808469125222
# Test error after step 146: 0.9265113723550503
# Train error after step 147: 0.7924807285965021
# Test error after step 147: 0.9265116869992227
# Train error after step 148: 0.7924806136915458
# Test error after step 148: 0.9265119945234932
# Train error after step 149: 0.7924805020885566
# Test error after step 149: 0.9265122950835432
# Train error after step 150: 0.7924803936823064
# Test error after step 150: 0.9265125888323494
# Train error after step 151: 0.792480288371285
# Test error after step 151: 0.9265128759201645
# Train error after step 152: 0.7924801860575543
# Test error after step 152: 0.9265131564945033
# Train error after step 153: 0.7924800866466097
# Test error after step 153: 0.9265134307001367
# Train error after step 154: 0.7924799900472463
# Test error after step 154: 0.9265136986790916
# Train error after step 155: 0.7924798961714329
# Test error after step 155: 0.9265139605706558
# Train error after step 156: 0.7924798049341885
# Test error after step 156: 0.9265142165113885
# Train error after step 157: 0.7924797162534674
# Test error after step 157: 0.9265144666351349
# Train error after step 158: 0.7924796300500471
# Test error after step 158: 0.9265147110730441
# Train error after step 159: 0.792479546247422
# Test error after step 159: 0.9265149499535915
# Train error after step 160: 0.7924794647716994
# Test error after step 160: 0.926515183402603
# Train error after step 161: 0.7924793855515033
# Test error after step 161: 0.9265154115432839
# Train error after step 162: 0.7924793085178791
# Test error after step 162: 0.9265156344962473
# Train error after step 163: 0.7924792336042039
# Test error after step 163: 0.9265158523795479
# Train error after step 164: 0.7924791607461003
# Test error after step 164: 0.9265160653087144
# Train error after step 165: 0.7924790898813519
# Test error after step 165: 0.9265162733967853
# Train error after step 166: 0.792479020949826
# Test error after step 166: 0.9265164767543467
# Train error after step 167: 0.7924789538933954
# Test error after step 167: 0.9265166754895683
# Train error after step 168: 0.7924788886558658
# Test error after step 168: 0.9265168697082437
# Train error after step 169: 0.7924788251829048
# Test error after step 169: 0.9265170595138286
# Train error after step 170: 0.7924787634219755
# Test error after step 170: 0.9265172450074828
# Train error after step 171: 0.7924787033222698
# Test error after step 171: 0.9265174262881077
# Train error after step 172: 0.792478644834647
# Test error after step 172: 0.9265176034523905
# Train error after step 173: 0.792478587911574
# Test error after step 173: 0.926517776594842
# Train error after step 174: 0.7924785325070672
# Test error after step 174: 0.9265179458078409
# Train error after step 175: 0.7924784785766374
# Test error after step 175: 0.9265181111816724
# Train error after step 176: 0.7924784260772364
# Test error after step 176: 0.9265182728045706
# Train error after step 177: 0.7924783749672059
# Test error after step 177: 0.9265184307627586
# Train error after step 178: 0.792478325206228
# Test error after step 178: 0.9265185851404896
# Train error after step 179: 0.7924782767552787
# Test error after step 179: 0.926518736020088
# Train error after step 180: 0.7924782295765816
# Test error after step 180: 0.9265188834819879
# Train error after step 181: 0.7924781836335635
# Test error after step 181: 0.926519027604774
# Train error after step 182: 0.7924781388908148
# Test error after step 182: 0.9265191684652209
# Train error after step 183: 0.7924780953140461
# Test error after step 183: 0.9265193061383307
# Train error after step 184: 0.7924780528700501
# Test error after step 184: 0.9265194406973726
# Train error after step 185: 0.7924780115266656
# Test error after step 185: 0.9265195722139203
# Train error after step 186: 0.7924779712527394
# Test error after step 186: 0.9265197007578889
# Train error after step 187: 0.7924779320180925
# Test error after step 187: 0.9265198263975717
# Train error after step 188: 0.7924778937934862
# Test error after step 188: 0.9265199491996768
# Train error after step 189: 0.7924778565505902
# Test error after step 189: 0.926520069229362
# Train error after step 190: 0.7924778202619508
# Test error after step 190: 0.92652018655027
# Train error after step 191: 0.7924777849009634
# Test error after step 191: 0.9265203012245625
# Train error after step 192: 0.7924777504418404
# Test error after step 192: 0.9265204133129546
# Train error after step 193: 0.7924777168595856
# Test error after step 193: 0.9265205228747472
# Train error after step 194: 0.7924776841299667
# Test error after step 194: 0.9265206299678587
# Train error after step 195: 0.7924776522294905
# Test error after step 195: 0.9265207346488586
# Train error after step 196: 0.7924776211353765
# Test error after step 196: 0.926520836972997
# Train error after step 197: 0.7924775908255347
# Test error after step 197: 0.9265209369942367
# Train error after step 198: 0.7924775612785419
# Test error after step 198: 0.9265210347652816
# Train error after step 199: 0.7924775324736185
# Test error after step 199: 0.9265211303376067
# Train error after step 200: 0.7924775043906095
# Test error after step 200: 0.9265212237614874
# Train error after step 201: 0.7924774770099611
# Test error after step 201: 0.9265213150860262
# Train error after step 202: 0.7924774503127034
# Test error after step 202: 0.9265214043591814
# Train error after step 203: 0.7924774242804291
# Test error after step 203: 0.926521491627793
# Train error after step 204: 0.7924773988952762
# Test error after step 204: 0.9265215769376102
# Train error after step 205: 0.7924773741399106
# Test error after step 205: 0.9265216603333161
# Train error after step 206: 0.7924773499975072
# Test error after step 206: 0.9265217418585533
# Train error after step 207: 0.7924773264517352
# Test error after step 207: 0.9265218215559478
# Train error after step 208: 0.7924773034867411
# Test error after step 208: 0.926521899467134
# Train error after step 209: 0.792477281087134
# Test error after step 209: 0.9265219756327774
# Train error after step 210: 0.7924772592379694
# Test error after step 210: 0.9265220500925979
# Train error after step 211: 0.7924772379247361
# Test error after step 211: 0.926522122885392
# Train error after step 212: 0.7924772171333422
# Test error after step 212: 0.9265221940490556
# Train error after step 213: 0.7924771968501009
# Test error after step 213: 0.9265222636206032
# Train error after step 214: 0.7924771770617186
# Test error after step 214: 0.9265223316361907
# Train error after step 215: 0.792477157755282
# Test error after step 215: 0.9265223981311355
# Train error after step 216: 0.792477138918246
# Test error after step 216: 0.9265224631399356
# Train error after step 217: 0.7924771205384226
# Test error after step 217: 0.9265225266962899
# Train error after step 218: 0.7924771026039688
# Test error after step 218: 0.9265225888331167
# Train error after step 219: 0.7924770851033766
# Test error after step 219: 0.9265226495825717
# Train error after step 220: 0.792477068025462
# Test error after step 220: 0.9265227089760678
# Train error after step 221: 0.7924770513593558
# Test error after step 221: 0.9265227670442905
# Train error after step 222: 0.7924770350944923
# Test error after step 222: 0.9265228238172167
# Train error after step 223: 0.792477019220602
# Test error after step 223: 0.9265228793241315
# Train error after step 224: 0.7924770037277002
# Test error after step 224: 0.9265229335936432
# Train error after step 225: 0.7924769886060798
# Test error after step 225: 0.9265229866537007
# Train error after step 226: 0.7924769738463028
# Test error after step 226: 0.9265230385316088
# Train error after step 227: 0.7924769594391913
# Test error after step 227: 0.9265230892540435
# Train error after step 228: 0.7924769453758196
# Test error after step 228: 0.926523138847066
# Train error after step 229: 0.7924769316475073
# Test error after step 229: 0.9265231873361385
# Train error after step 230: 0.7924769182458116
# Test error after step 230: 0.9265232347461373
# Train error after step 231: 0.7924769051625196
# Test error after step 231: 0.9265232811013677
# Train error after step 232: 0.7924768923896423
# Test error after step 232: 0.9265233264255766
# Train error after step 233: 0.7924768799194073
# Test error after step 233: 0.9265233707419656
# Train error after step 234: 0.7924768677442516
# Test error after step 234: 0.9265234140732048
# Train error after step 235: 0.7924768558568177
# Test error after step 235: 0.9265234564414448
# Train error after step 236: 0.7924768442499447
# Test error after step 236: 0.9265234978683278
# Train error after step 237: 0.7924768329166646
# Test error after step 237: 0.9265235383750022
# Train error after step 238: 0.7924768218501957
# Test error after step 238: 0.9265235779821315
# Train error after step 239: 0.7924768110439369
# Test error after step 239: 0.9265236167099067
# Train error after step 240: 0.7924768004914629
# Test error after step 240: 0.9265236545780586
# Train error after step 241: 0.7924767901865193
# Test error after step 241: 0.9265236916058665
# Train error after step 242: 0.7924767801230165
# Test error after step 242: 0.9265237278121699
# Train error after step 243: 0.7924767702950264
# Test error after step 243: 0.9265237632153789
# Train error after step 244: 0.7924767606967765
# Test error after step 244: 0.9265237978334849
# Train error after step 245: 0.7924767513226465
# Test error after step 245: 0.9265238316840676
# Train error after step 246: 0.7924767421671625
# Test error after step 246: 0.9265238647843083
# Train error after step 247: 0.792476733224994
# Test error after step 247: 0.9265238971509964
# Train error after step 248: 0.79247672449095
# Test error after step 248: 0.9265239288005399
# Train error after step 249: 0.7924767159599736
# Test error after step 249: 0.926523959748974
# Train error after step 250: 0.7924767076271394
# Test error after step 250: 0.9265239900119701
# Train error after step 251: 0.7924766994876494
# Test error after step 251: 0.9265240196048432
# Train error after step 252: 0.7924766915368302
# Test error after step 252: 0.9265240485425612
# Train error after step 253: 0.792476683770127
# Test error after step 253: 0.9265240768397529
# Train error after step 254: 0.7924766761831039
# Test error after step 254: 0.9265241045107159
# Train error after step 255: 0.7924766687714372
# Test error after step 255: 0.9265241315694229
# Train error after step 256: 0.7924766615309146
# Test error after step 256: 0.9265241580295313
# Train error after step 257: 0.7924766544574311
# Test error after step 257: 0.9265241839043895
# Train error after step 258: 0.7924766475469859
# Test error after step 258: 0.9265242092070441
# Train error after step 259: 0.7924766407956803
# Test error after step 259: 0.9265242339502461
# Train error after step 260: 0.7924766341997139
# Test error after step 260: 0.9265242581464597
# Train error after step 261: 0.7924766277553824
# Test error after step 261: 0.9265242818078666
# Train error after step 262: 0.7924766214590754
# Test error after step 262: 0.9265243049463748
# Train error after step 263: 0.7924766153072732
# Test error after step 263: 0.9265243275736229
# Train error after step 264: 0.792476609296544
# Test error after step 264: 0.9265243497009875
# Train error after step 265: 0.7924766034235428
# Test error after step 265: 0.9265243713395886
# Train error after step 266: 0.7924765976850078
# Test error after step 266: 0.9265243925002966
# Train error after step 267: 0.7924765920777589
# Test error after step 267: 0.9265244131937365
# Train error after step 268: 0.7924765865986949
# Test error after step 268: 0.9265244334302941
# Train error after step 269: 0.792476581244792
# Test error after step 269: 0.9265244532201221
# Train error after step 270: 0.7924765760131011
# Test error after step 270: 0.9265244725731451
# Train error after step 271: 0.7924765709007466
# Test error after step 271: 0.9265244914990641
# Train error after step 272: 0.7924765659049239
# Test error after step 272: 0.9265245100073636
# Train error after step 273: 0.792476561022897
# Test error after step 273: 0.9265245281073137
# Train error after step 274: 0.7924765562519981
# Test error after step 274: 0.926524545807977
# Train error after step 275: 0.7924765515896243
# Test error after step 275: 0.9265245631182133
# Train error after step 276: 0.7924765470332369
# Test error after step 276: 0.926524580046683
# Train error after step 277: 0.7924765425803594
# Test error after step 277: 0.926524596601853
# Train error after step 278: 0.7924765382285758
# Test error after step 278: 0.9265246127920007
# Train error after step 279: 0.792476533975529
# Test error after step 279: 0.9265246286252176
# Train error after step 280: 0.7924765298189193
# Test error after step 280: 0.9265246441094145
# Train error after step 281: 0.7924765257565028
# Test error after step 281: 0.9265246592523246
# Train error after step 282: 0.7924765217860907
# Test error after step 282: 0.9265246740615091
# Train error after step 283: 0.792476517905546
# Test error after step 283: 0.9265246885443594
# Train error after step 284: 0.7924765141127852
# Test error after step 284: 0.9265247027081022
# Train error after step 285: 0.792476510405773
# Test error after step 285: 0.9265247165598018
# Train error after step 286: 0.7924765067825253
# Test error after step 286: 0.9265247301063663
# Train error after step 287: 0.7924765032411049
# Test error after step 287: 0.9265247433545483
# Train error after step 288: 0.79247649977962
# Test error after step 288: 0.9265247563109504
# Train error after step 289: 0.7924764963962263
# Test error after step 289: 0.9265247689820272
# Train error after step 290: 0.7924764930891223
# Test error after step 290: 0.9265247813740899
# Train error after step 291: 0.7924764898565501
# Test error after step 291: 0.9265247934933089
# Train error after step 292: 0.7924764866967935
# Test error after step 292: 0.9265248053457167
# Train error after step 293: 0.7924764836081779
# Test error after step 293: 0.9265248169372126
# Train error after step 294: 0.792476480589068
# Test error after step 294: 0.9265248282735626
# Train error after step 295: 0.7924764776378679
# Test error after step 295: 0.9265248393604057
# Train error after step 296: 0.792476474753019
# Test error after step 296: 0.9265248502032555
# Train error after step 297: 0.7924764719330002
# Test error after step 297: 0.9265248608075014
# Train error after step 298: 0.7924764691763263
# Test error after step 298: 0.9265248711784145
# Train error after step 299: 0.7924764664815472
# Test error after step 299: 0.926524881321148
# Train error after step 300: 0.7924764638472475
# Test error after step 300: 0.9265248912407406
# Train error after step 301: 0.7924764612720441
# Test error after step 301: 0.9265249009421185
# Train error after step 302: 0.7924764587545882
# Test error after step 302: 0.9265249104300994
# Train error after step 303: 0.7924764562935611
# Test error after step 303: 0.9265249197093933
# Train error after step 304: 0.7924764538876757
# Test error after step 304: 0.9265249287846057
# Train error after step 305: 0.7924764515356763
# Test error after step 305: 0.9265249376602397
# Train error after step 306: 0.7924764492363348
# Test error after step 306: 0.9265249463406992
# Train error after step 307: 0.7924764469884529
# Test error after step 307: 0.926524954830289
# Train error after step 308: 0.7924764447908602
# Test error after step 308: 0.9265249631332195
# Train error after step 309: 0.7924764426424139
# Test error after step 309: 0.9265249712536076
# Train error after step 310: 0.7924764405419973
# Test error after step 310: 0.926524979195478
# Train error after step 311: 0.7924764384885203
# Test error after step 311: 0.9265249869627673
# Train error after step 312: 0.792476436480918
# Test error after step 312: 0.9265249945593241
# Train error after step 313: 0.7924764345181503
# Test error after step 313: 0.9265250019889121
# Train error after step 314: 0.792476432599201
# Test error after step 314: 0.9265250092552112
# Train error after step 315: 0.7924764307230784
# Test error after step 315: 0.9265250163618198
# Train error after step 316: 0.7924764288888128
# Test error after step 316: 0.9265250233122573
# Train error after step 317: 0.7924764270954573
# Test error after step 317: 0.9265250301099646
# Train error after step 318: 0.7924764253420874
# Test error after step 318: 0.9265250367583062
# Train error after step 319: 0.7924764236277996
# Test error after step 319: 0.9265250432605727
# Train error after step 320: 0.792476421951711
# Test error after step 320: 0.9265250496199814
# Train error after step 321: 0.7924764203129598
# Test error after step 321: 0.9265250558396783
# Train error after step 322: 0.7924764187107036
# Test error after step 322: 0.9265250619227405
# Train error after step 323: 0.7924764171441196
# Test error after step 323: 0.9265250678721766
# Train error after step 324: 0.7924764156124037
# Test error after step 324: 0.9265250736909287
# Train error after step 325: 0.7924764141147705
# Test error after step 325: 0.9265250793818737
# Train error after step 326: 0.792476412650453
# Test error after step 326: 0.9265250849478249
# Train error after step 327: 0.7924764112187013
# Test error after step 327: 0.926525090391534
# Train error after step 328: 0.792476409818783
# Test error after step 328: 0.9265250957156913
# Train error after step 329: 0.7924764084499821
# Test error after step 329: 0.9265251009229274
# Train error after step 330: 0.7924764071115997
# Test error after step 330: 0.9265251060158155
# Train error after step 331: 0.7924764058029522
# Test error after step 331: 0.9265251109968722
# Train error after step 332: 0.7924764045233724
# Test error after step 332: 0.9265251158685565
# Train error after step 333: 0.7924764032722075
# Test error after step 333: 0.926525120633276
# Train error after step 334: 0.7924764020488204
# Test error after step 334: 0.9265251252933835
# Train error after step 335: 0.7924764008525881
# Test error after step 335: 0.9265251298511794
# Train error after step 336: 0.7924763996829018
# Test error after step 336: 0.9265251343089145
# Train error after step 337: 0.7924763985391671
# Test error after step 337: 0.9265251386687894
# Train error after step 338: 0.792476397420802
# Test error after step 338: 0.9265251429329558
# Train error after step 339: 0.7924763963272394
# Test error after step 339: 0.9265251471035189
# Train error after step 340: 0.7924763952579235
# Test error after step 340: 0.9265251511825363
# Train error after step 341: 0.7924763942123124
# Test error after step 341: 0.9265251551720213
# Train error after step 342: 0.7924763931898754
# Test error after step 342: 0.9265251590739417
# Train error after step 343: 0.7924763921900947
# Test error after step 343: 0.9265251628902228
# Train error after step 344: 0.7924763912124643
# Test error after step 344: 0.9265251666227473
# Train error after step 345: 0.7924763902564889
# Test error after step 345: 0.926525170273356
# Train error after step 346: 0.7924763893216848
# Test error after step 346: 0.9265251738438494
# Train error after step 347: 0.7924763884075797
# Test error after step 347: 0.9265251773359879
# Train error after step 348: 0.7924763875137114
# Test error after step 348: 0.9265251807514945
# Train error after step 349: 0.7924763866396287
# Test error after step 349: 0.9265251840920521
# Train error after step 350: 0.7924763857848899
# Test error after step 350: 0.926525187359308
# Train error after step 351: 0.7924763849490644
# Test error after step 351: 0.9265251905548734
# Train error after step 352: 0.7924763841317293
# Test error after step 352: 0.9265251936803224
# Train error after step 353: 0.7924763833324738
# Test error after step 353: 0.9265251967371959
# Train error after step 354: 0.7924763825508947
# Test error after step 354: 0.9265251997270009
# Train error after step 355: 0.7924763817865983
# Test error after step 355: 0.9265252026512103
# Train error after step 356: 0.7924763810391996
# Test error after step 356: 0.9265252055112649
# Train error after step 357: 0.792476380308323
# Test error after step 357: 0.9265252083085744
# Train error after step 358: 0.7924763795936004
# Test error after step 358: 0.9265252110445165
# Train error after step 359: 0.7924763788946727
# Test error after step 359: 0.9265252137204392
# Train error after step 360: 0.7924763782111883
# Test error after step 360: 0.9265252163376606
# Train error after step 361: 0.7924763775428041
# Test error after step 361: 0.9265252188974699
# Train error after step 362: 0.7924763768891843
# Test error after step 362: 0.9265252214011277
# Train error after step 363: 0.7924763762500008
# Test error after step 363: 0.9265252238498676
# Train error after step 364: 0.792476375624933
# Test error after step 364: 0.9265252262448951
# Train error after step 365: 0.7924763750136673
# Test error after step 365: 0.9265252285873896
# Train error after step 366: 0.792476374415897
# Test error after step 366: 0.9265252308785046
# Train error after step 367: 0.7924763738313224
# Test error after step 367: 0.9265252331193675
# Train error after step 368: 0.7924763732596509
# Test error after step 368: 0.9265252353110828
# Train error after step 369: 0.7924763727005959
# Test error after step 369: 0.9265252374547285
# Train error after step 370: 0.792476372153878
# Test error after step 370: 0.9265252395513602
# Train error after step 371: 0.7924763716192228
# Test error after step 371: 0.92652524160201
# Train error after step 372: 0.792476371096363
# Test error after step 372: 0.9265252436076873
# Train error after step 373: 0.7924763705850371
# Test error after step 373: 0.926525245569379
# Train error after step 374: 0.7924763700849894
# Test error after step 374: 0.9265252474880507
# Train error after step 375: 0.7924763695959698
# Test error after step 375: 0.9265252493646464
# Train error after step 376: 0.7924763691177346
# Test error after step 376: 0.9265252512000901
# Train error after step 377: 0.7924763686500438
# Test error after step 377: 0.9265252529952843
# Train error after step 378: 0.7924763681926646
# Test error after step 378: 0.9265252547511131
# Train error after step 379: 0.7924763677453682
# Test error after step 379: 0.9265252564684396
# Train error after step 380: 0.7924763673079313
# Test error after step 380: 0.9265252581481093
# Train error after step 381: 0.7924763668801359
# Test error after step 381: 0.9265252597909481
# Train error after step 382: 0.7924763664617686
# Test error after step 382: 0.9265252613977647
# Train error after step 383: 0.7924763660526203
# Test error after step 383: 0.9265252629693491
# Train error after step 384: 0.7924763656524876
# Test error after step 384: 0.9265252645064748
# Train error after step 385: 0.7924763652611706
# Test error after step 385: 0.926525266009897
# Train error after step 386: 0.7924763648784744
# Test error after step 386: 0.9265252674803562
# Train error after step 387: 0.7924763645042082
# Test error after step 387: 0.9265252689185752
# Train error after step 388: 0.7924763641381859
# Test error after step 388: 0.9265252703252613
# Train error after step 389: 0.792476363780225
# Test error after step 389: 0.9265252717011063
# Train error after step 390: 0.792476363430147
# Test error after step 390: 0.9265252730467869
# Train error after step 391: 0.7924763630877784
# Test error after step 391: 0.9265252743629647
# Train error after step 392: 0.7924763627529483
# Test error after step 392: 0.9265252756502872
# Train error after step 393: 0.79247636242549
# Test error after step 393: 0.9265252769093869
# Train error after step 394: 0.792476362105241
# Test error after step 394: 0.9265252781408835
# Train error after step 395: 0.7924763617920417
# Test error after step 395: 0.9265252793453818
# Train error after step 396: 0.7924763614857367
# Test error after step 396: 0.9265252805234745
# Train error after step 397: 0.7924763611861734
# Test error after step 397: 0.9265252816757404
# Train error after step 398: 0.7924763608932033
# Test error after step 398: 0.9265252828027468
# Train error after step 399: 0.7924763606066806
# Test error after step 399: 0.9265252839050468
# Train error after step 400: 0.792476360326463
# Test error after step 400: 0.9265252849831828
# Train error after step 401: 0.7924763600524113
# Test error after step 401: 0.9265252860376846
# Train error after step 402: 0.7924763597843895
# Test error after step 402: 0.9265252870690708
# Train error after step 403: 0.7924763595222644
# Test error after step 403: 0.926525288077848
# Train error after step 404: 0.7924763592659059
# Test error after step 404: 0.9265252890645121
# Train error after step 405: 0.7924763590151866
# Test error after step 405: 0.9265252900295483
# Train error after step 406: 0.7924763587699827
# Test error after step 406: 0.9265252909734308
# Train error after step 407: 0.792476358530172
# Test error after step 407: 0.9265252918966236
# Train error after step 408: 0.7924763582956357
# Test error after step 408: 0.92652529279958
# Train error after step 409: 0.7924763580662577
# Test error after step 409: 0.9265252936827444
# Train error after step 410: 0.7924763578419236
# Test error after step 410: 0.9265252945465502
# Train error after step 411: 0.7924763576225228
# Test error after step 411: 0.9265252953914221
# Train error after step 412: 0.7924763574079463
# Test error after step 412: 0.9265252962177757
# Train error after step 413: 0.7924763571980881
# Test error after step 413: 0.9265252970260164
# Train error after step 414: 0.7924763569928436
# Test error after step 414: 0.9265252978165417
# Train error after step 415: 0.7924763567921115
# Test error after step 415: 0.9265252985897403
# Train error after step 416: 0.7924763565957922
# Test error after step 416: 0.9265252993459916
# Train error after step 417: 0.7924763564037886
# Test error after step 417: 0.9265253000856674
# Train error after step 418: 0.7924763562160055
# Test error after step 418: 0.9265253008091312
# Train error after step 419: 0.7924763560323501
# Test error after step 419: 0.9265253015167383
# Train error after step 420: 0.7924763558527312
# Test error after step 420: 0.9265253022088368
# Train error after step 421: 0.7924763556770601
# Test error after step 421: 0.9265253028857662
# Train error after step 422: 0.7924763555052495
# Test error after step 422: 0.9265253035478593
# Train error after step 423: 0.7924763553372149
# Test error after step 423: 0.9265253041954413
# Train error after step 424: 0.7924763551728726
# Test error after step 424: 0.9265253048288303
# Train error after step 425: 0.7924763550121419
# Test error after step 425: 0.9265253054483378
# Train error after step 426: 0.7924763548549428
# Test error after step 426: 0.9265253060542677
# Train error after step 427: 0.7924763547011977
# Test error after step 427: 0.9265253066469179
# Train error after step 428: 0.7924763545508308
# Test error after step 428: 0.9265253072265794
# Train error after step 429: 0.7924763544037668
# Test error after step 429: 0.9265253077935371
# Train error after step 430: 0.7924763542599342
# Test error after step 430: 0.9265253083480695
# Train error after step 431: 0.7924763541192614
# Test error after step 431: 0.9265253088904487
# Train error after step 432: 0.7924763539816788
# Test error after step 432: 0.9265253094209415
# Train error after step 433: 0.7924763538471181
# Test error after step 433: 0.926525309939808
# Train error after step 434: 0.7924763537155134
# Test error after step 434: 0.9265253104473036
# Train error after step 435: 0.7924763535867992
# Test error after step 435: 0.926525310943677
# Train error after step 436: 0.7924763534609122
# Test error after step 436: 0.9265253114291728
# Train error after step 437: 0.7924763533377901
# Test error after step 437: 0.9265253119040285
# Train error after step 438: 0.7924763532173721
# Test error after step 438: 0.9265253123684781
# Train error after step 439: 0.7924763530995986
# Test error after step 439: 0.9265253128227493
# Train error after step 440: 0.7924763529844113
# Test error after step 440: 0.9265253132670653
# Train error after step 441: 0.7924763528717537
# Test error after step 441: 0.9265253137016443
# Train error after step 442: 0.7924763527615696
# Test error after step 442: 0.9265253141266998
# Train error after step 443: 0.7924763526538054
# Test error after step 443: 0.9265253145424406
# Train error after step 444: 0.7924763525484071
# Test error after step 444: 0.9265253149490704
# Train error after step 445: 0.7924763524453232
# Test error after step 445: 0.9265253153467894
# Train error after step 446: 0.7924763523445028
# Test error after step 446: 0.9265253157357929
# Train error after step 447: 0.7924763522458956
# Test error after step 447: 0.9265253161162719
# Train error after step 448: 0.7924763521494537
# Test error after step 448: 0.926525316488413
# Train error after step 449: 0.7924763520551289
# Test error after step 449: 0.926525316852399
# Train error after step 450: 0.7924763519628747
# Test error after step 450: 0.9265253172084091
# Train error after step 451: 0.7924763518726461
# Test error after step 451: 0.9265253175566176
# Train error after step 452: 0.7924763517843979
# Test error after step 452: 0.9265253178971955
# Train error after step 453: 0.7924763516980868
# Test error after step 453: 0.9265253182303101
# Train error after step 454: 0.7924763516136706
# Test error after step 454: 0.9265253185561254
# Train error after step 455: 0.7924763515311073
# Test error after step 455: 0.9265253188748008
# Train error after step 456: 0.7924763514503561
# Test error after step 456: 0.926525319186493
# Train error after step 457: 0.7924763513713774
# Test error after step 457: 0.9265253194913553
# Train error after step 458: 0.7924763512941321
# Test error after step 458: 0.9265253197895371
# Train error after step 459: 0.792476351218582
# Test error after step 459: 0.9265253200811846
# Train error after step 460: 0.7924763511446903
# Test error after step 460: 0.9265253203664413
# Train error after step 461: 0.7924763510724203
# Test error after step 461: 0.9265253206454477
# Train error after step 462: 0.7924763510017362
# Test error after step 462: 0.9265253209183403
# Train error after step 463: 0.7924763509326035
# Test error after step 463: 0.9265253211852527
# Train error after step 464: 0.7924763508649878
# Test error after step 464: 0.9265253214463169
# Train error after step 465: 0.7924763507988559
# Test error after step 465: 0.9265253217016601
# Train error after step 466: 0.792476350734175
# Test error after step 466: 0.9265253219514081
# Train error after step 467: 0.7924763506709137
# Test error after step 467: 0.9265253221956837
# Train error after step 468: 0.7924763506090405
# Test error after step 468: 0.9265253224346067
# Train error after step 469: 0.792476350548525
# Test error after step 469: 0.9265253226682945
# Train error after step 470: 0.7924763504893373
# Test error after step 470: 0.9265253228968616
# Train error after step 471: 0.7924763504314479
# Test error after step 471: 0.9265253231204204
# Train error after step 472: 0.792476350374829
# Test error after step 472: 0.9265253233390804
# Train error after step 473: 0.7924763503194524
# Test error after step 473: 0.9265253235529494
# Train error after step 474: 0.792476350265291
# Test error after step 474: 0.9265253237621318
# Train error after step 475: 0.7924763502123174
# Test error after step 475: 0.9265253239667307
# Train error after step 476: 0.792476350160506
# Test error after step 476: 0.9265253241668466
# Train error after step 477: 0.7924763501098318
# Test error after step 477: 0.9265253243625778
# Train error after step 478: 0.7924763500602688
# Test error after step 478: 0.9265253245540199
# Train error after step 479: 0.7924763500117934
# Test error after step 479: 0.926525324741267
# Train error after step 480: 0.7924763499643813
# Test error after step 480: 0.9265253249244115
# Train error after step 481: 0.7924763499180093
# Test error after step 481: 0.9265253251035432
# Train error after step 482: 0.7924763498726547
# Test error after step 482: 0.9265253252787496
# Train error after step 483: 0.7924763498282948
# Test error after step 483: 0.9265253254501172
# Train error after step 484: 0.7924763497849081
# Test error after step 484: 0.9265253256177298
# Train error after step 485: 0.7924763497424733
# Test error after step 485: 0.9265253257816697
# Train error after step 486: 0.7924763497009688
# Test error after step 486: 0.9265253259420174
# Train error after step 487: 0.7924763496603753
# Test error after step 487: 0.9265253260988522
# Train error after step 488: 0.7924763496206719
# Test error after step 488: 0.9265253262522499
# Train error after step 489: 0.7924763495818392
# Test error after step 489: 0.9265253264022869
# Train error after step 490: 0.7924763495438586
# Test error after step 490: 0.9265253265490361
# Train error after step 491: 0.7924763495067108
# Test error after step 491: 0.92652532669257
# Train error after step 492: 0.7924763494703777
# Test error after step 492: 0.9265253268329591
# Train error after step 493: 0.7924763494348417
# Test error after step 493: 0.9265253269702722
# Train error after step 494: 0.792476349400085
# Test error after step 494: 0.9265253271045766
# Train error after step 495: 0.7924763493660906
# Test error after step 495: 0.9265253272359382
# Train error after step 496: 0.7924763493328416
# Test error after step 496: 0.9265253273644212
# Train error after step 497: 0.7924763493003218
# Test error after step 497: 0.9265253274900893
# Train error after step 498: 0.7924763492685156
# Test error after step 498: 0.9265253276130041
# Train error after step 499: 0.7924763492374066
# Test error after step 499: 0.9265253277332255
# Train error after step 500: 0.7924763492069801
# Test error after step 500: 0.9265253278508128
# Train error after step 501: 0.7924763491772204
# Test error after step 501: 0.9265253279658238
# Train error after step 502: 0.7924763491481138
# Test error after step 502: 0.9265253280783148
# Train error after step 503: 0.7924763491196452
# Test error after step 503: 0.926525328188341
# Train error after step 504: 0.7924763490918012
# Test error after step 504: 0.9265253282959566
# Train error after step 505: 0.7924763490645675
# Test error after step 505: 0.9265253284012142
# Train error after step 506: 0.7924763490379311
# Test error after step 506: 0.9265253285041656
# Train error after step 507: 0.7924763490118788
# Test error after step 507: 0.9265253286048609
# Train error after step 508: 0.7924763489863977
# Test error after step 508: 0.9265253287033504
# Train error after step 509: 0.7924763489614756
# Test error after step 509: 0.9265253287996817
# Train error after step 510: 0.7924763489370996
# Test error after step 510: 0.9265253288939024
# Train error after step 511: 0.7924763489132584
# Test error after step 511: 0.9265253289860585
# Train error after step 512: 0.7924763488899399
# Test error after step 512: 0.9265253290761958
# Train error after step 513: 0.7924763488671327
# Test error after step 513: 0.9265253291643581
# Train error after step 514: 0.7924763488448254
# Test error after step 514: 0.9265253292505887
# Train error after step 515: 0.7924763488230074
# Test error after step 515: 0.9265253293349297
# Train error after step 516: 0.7924763488016678
# Test error after step 516: 0.9265253294174232
# Train error after step 517: 0.7924763487807961
# Test error after step 517: 0.9265253294981088
# Train error after step 518: 0.7924763487603822
# Test error after step 518: 0.9265253295770269
# Train error after step 519: 0.7924763487404154
# Test error after step 519: 0.9265253296542156
# Train error after step 520: 0.7924763487208869
# ...
# Test error after step 828: 0.9265253330964165
# Train error after step 829: 0.792476347850397
# Test error after step 829: 0.9265253330964967
# Train error after step 830: 0.7924763478503766
# Test error after step 830: 0.9265253330965751
# Train error after step 831: 0.7924763478503567
# Test error after step 831: 0.9265253330966522
# Train error after step 832: 0.7924763478503374
# Test error after step 832: 0.9265253330967275
# Train error after step 833: 0.7924763478503183
# Test error after step 833: 0.9265253330968009
# Train error after step 834: 0.7924763478502996
# Test error after step 834: 0.926525333096873
# Train error after step 835: 0.7924763478502814
# Test error after step 835: 0.9265253330969433
# Train error after step 836: 0.7924763478502636
# Test error after step 836: 0.9265253330970119
# Train error after step 837: 0.7924763478502463
# Test error after step 837: 0.9265253330970792
# Train error after step 838: 0.7924763478502294
# Test error after step 838: 0.9265253330971451
# Train error after step 839: 0.7924763478502128
# Test error after step 839: 0.9265253330972095
# Train error after step 840: 0.7924763478501966
# Test error after step 840: 0.9265253330972725
# Train error after step 841: 0.7924763478501806
# Test error after step 841: 0.9265253330973342
# Train error after step 842: 0.792476347850165
# Test error after step 842: 0.9265253330973945
# Train error after step 843: 0.7924763478501498
# Test error after step 843: 0.9265253330974534
# Train error after step 844: 0.792476347850135
# Test error after step 844: 0.9265253330975111
# Train error after step 845: 0.7924763478501203
# Test error after step 845: 0.9265253330975673
# Train error after step 846: 0.792476347850106
# Test error after step 846: 0.9265253330976226
# Train error after step 847: 0.7924763478500921
# Test error after step 847: 0.9265253330976765
# Train error after step 848: 0.7924763478500785
# Test error after step 848: 0.9265253330977293
# Train error after step 849: 0.7924763478500652
# Test error after step 849: 0.9265253330977807
# Train error after step 850: 0.7924763478500519
# Test error after step 850: 0.9265253330978312
# Train error after step 851: 0.7924763478500393
# Test error after step 851: 0.9265253330978808
# Train error after step 852: 0.7924763478500267
# Test error after step 852: 0.9265253330979291
# Train error after step 853: 0.7924763478500148
# Test error after step 853: 0.9265253330979762
# Train error after step 854: 0.7924763478500025
# Test error after step 854: 0.9265253330980225
# Train error after step 855: 0.792476347849991
# Test error after step 855: 0.9265253330980678
# Train error after step 856: 0.7924763478499794
# Test error after step 856: 0.9265253330981118
# Train error after step 857: 0.7924763478499686
# Test error after step 857: 0.9265253330981551
# Train error after step 858: 0.7924763478499576
# Test error after step 858: 0.9265253330981972
# Train error after step 859: 0.792476347849947
# Test error after step 859: 0.9265253330982387
# Train error after step 860: 0.7924763478499364
# Test error after step 860: 0.9265253330982791
# Train error after step 861: 0.7924763478499265
# Test error after step 861: 0.9265253330983186
# Train error after step 862: 0.7924763478499163
# Test error after step 862: 0.9265253330983574
# Train error after step 863: 0.7924763478499064
# Test error after step 863: 0.926525333098395
# Train error after step 864: 0.7924763478498968
# Test error after step 864: 0.9265253330984322
# Train error after step 865: 0.7924763478498874
# Test error after step 865: 0.9265253330984682
# Train error after step 866: 0.7924763478498783
# Test error after step 866: 0.9265253330985038
# Train error after step 867: 0.7924763478498694
# Test error after step 867: 0.9265253330985385
# Train error after step 868: 0.7924763478498608
# Test error after step 868: 0.9265253330985722
# Train error after step 869: 0.7924763478498522
# Test error after step 869: 0.9265253330986056
# Train error after step 870: 0.7924763478498438
# Test error after step 870: 0.9265253330986378
# Train error after step 871: 0.7924763478498356
# Test error after step 871: 0.9265253330986696
# Train error after step 872: 0.7924763478498278
# Test error after step 872: 0.9265253330987007
# Train error after step 873: 0.7924763478498197
# Test error after step 873: 0.9265253330987309
# Train error after step 874: 0.792476347849812
# Test error after step 874: 0.9265253330987606
# Train error after step 875: 0.7924763478498044
# Test error after step 875: 0.9265253330987896
# Train error after step 876: 0.7924763478497974
# Test error after step 876: 0.926525333098818
# Train error after step 877: 0.7924763478497899
# Test error after step 877: 0.9265253330988457
# Train error after step 878: 0.792476347849783
# Test error after step 878: 0.926525333098873
# Train error after step 879: 0.792476347849776
# Test error after step 879: 0.9265253330988997
# Train error after step 880: 0.7924763478497693
# Test error after step 880: 0.9265253330989255
# Train error after step 881: 0.792476347849763
# Test error after step 881: 0.9265253330989508
# Train error after step 882: 0.7924763478497565
# Test error after step 882: 0.9265253330989754
# Train error after step 883: 0.7924763478497502
# Test error after step 883: 0.9265253330989999
# Train error after step 884: 0.792476347849744
# Test error after step 884: 0.9265253330990234
# Train error after step 885: 0.7924763478497381
# Test error after step 885: 0.9265253330990469
# Train error after step 886: 0.7924763478497321
# Test error after step 886: 0.9265253330990695
# Train error after step 887: 0.7924763478497263
# Test error after step 887: 0.9265253330990918
# Train error after step 888: 0.7924763478497208
# Test error after step 888: 0.9265253330991137
# Train error after step 889: 0.7924763478497151
# Test error after step 889: 0.9265253330991349
# Train error after step 890: 0.7924763478497099
# Test error after step 890: 0.9265253330991557
# Train error after step 891: 0.7924763478497046
# Test error after step 891: 0.9265253330991762
# Train error after step 892: 0.7924763478496993
# Test error after step 892: 0.9265253330991958
# Train error after step 893: 0.7924763478496946
# Test error after step 893: 0.9265253330992154
# Train error after step 894: 0.7924763478496898
# Test error after step 894: 0.9265253330992346
# Train error after step 895: 0.7924763478496848
# Test error after step 895: 0.9265253330992531
# Train error after step 896: 0.7924763478496802
# Test error after step 896: 0.9265253330992713
# Train error after step 897: 0.7924763478496756
# Test error after step 897: 0.9265253330992891
# Train error after step 898: 0.7924763478496711
# Test error after step 898: 0.9265253330993067
# Train error after step 899: 0.7924763478496666
# Test error after step 899: 0.9265253330993237
# Train error after step 900: 0.7924763478496623
# Test error after step 900: 0.9265253330993403
# Train error after step 901: 0.7924763478496581
# Test error after step 901: 0.9265253330993566
# Train error after step 902: 0.792476347849654
# Test error after step 902: 0.9265253330993725
# Train error after step 903: 0.7924763478496499
# Test error after step 903: 0.9265253330993882
# Train error after step 904: 0.7924763478496459
# Test error after step 904: 0.9265253330994033
# Train error after step 905: 0.792476347849642
# Test error after step 905: 0.9265253330994183
# Train error after step 906: 0.7924763478496384
# Test error after step 906: 0.926525333099433
# Train error after step 907: 0.7924763478496346
# Test error after step 907: 0.9265253330994473
# Train error after step 908: 0.7924763478496312
# Test error after step 908: 0.9265253330994612
# Train error after step 909: 0.7924763478496274
# Test error after step 909: 0.9265253330994748
# Train error after step 910: 0.7924763478496241
# Test error after step 910: 0.9265253330994883
# Train error after step 911: 0.7924763478496206
# Test error after step 911: 0.9265253330995014
# Train error after step 912: 0.7924763478496175
# Test error after step 912: 0.9265253330995142
# Train error after step 913: 0.7924763478496143
# Test error after step 913: 0.9265253330995266
# Train error after step 914: 0.7924763478496111
# Test error after step 914: 0.9265253330995389
# Train error after step 915: 0.792476347849608
# Test error after step 915: 0.9265253330995507
# Train error after step 916: 0.7924763478496047
# Test error after step 916: 0.9265253330995623
# Train error after step 917: 0.792476347849602
# Test error after step 917: 0.926525333099574
# Train error after step 918: 0.792476347849599
# Test error after step 918: 0.9265253330995851
# Train error after step 919: 0.7924763478495962
# Test error after step 919: 0.9265253330995961
# Train error after step 920: 0.7924763478495931
# Test error after step 920: 0.9265253330996067
# Train error after step 921: 0.7924763478495906
# Test error after step 921: 0.9265253330996173
# Train error after step 922: 0.792476347849588
# Test error after step 922: 0.9265253330996274
# Train error after step 923: 0.7924763478495855
# Test error after step 923: 0.9265253330996374
# Train error after step 924: 0.7924763478495831
# Test error after step 924: 0.9265253330996472
# Train error after step 925: 0.7924763478495804
# Test error after step 925: 0.9265253330996567
# Train error after step 926: 0.792476347849578
# Test error after step 926: 0.9265253330996662
# Train error after step 927: 0.7924763478495757
# Test error after step 927: 0.9265253330996753
# Train error after step 928: 0.7924763478495733
# Test error after step 928: 0.9265253330996844
# Train error after step 929: 0.792476347849571
# Test error after step 929: 0.9265253330996931
# Train error after step 930: 0.7924763478495689
# Test error after step 930: 0.9265253330997016
# Train error after step 931: 0.7924763478495666
# Test error after step 931: 0.92652533309971
# Train error after step 932: 0.7924763478495646
# Test error after step 932: 0.9265253330997183
# Train error after step 933: 0.7924763478495624
# Test error after step 933: 0.9265253330997263
# Train error after step 934: 0.7924763478495604
# Test error after step 934: 0.9265253330997341
# Train error after step 935: 0.7924763478495586
# Test error after step 935: 0.926525333099742
# Train error after step 936: 0.7924763478495566
# Test error after step 936: 0.9265253330997496
# Train error after step 937: 0.7924763478495547
# Test error after step 937: 0.9265253330997568
# Train error after step 938: 0.7924763478495528
# Test error after step 938: 0.9265253330997638
# Train error after step 939: 0.7924763478495509
# Test error after step 939: 0.926525333099771
# Train error after step 940: 0.7924763478495489
# Test error after step 940: 0.9265253330997778
# Train error after step 941: 0.7924763478495473
# Test error after step 941: 0.9265253330997845
# Train error after step 942: 0.7924763478495457
# Test error after step 942: 0.9265253330997911
# Train error after step 943: 0.792476347849544
# Test error after step 943: 0.9265253330997973
# Train error after step 944: 0.7924763478495426
# Test error after step 944: 0.926525333099804
# Train error after step 945: 0.7924763478495409
# Test error after step 945: 0.92652533309981
# Train error after step 946: 0.7924763478495394
# Test error after step 946: 0.9265253330998159
# Train error after step 947: 0.7924763478495378
# Test error after step 947: 0.9265253330998218
# Train error after step 948: 0.7924763478495365
# Test error after step 948: 0.9265253330998277
# Train error after step 949: 0.7924763478495348
# Test error after step 949: 0.9265253330998333
# Train error after step 950: 0.7924763478495335
# Test error after step 950: 0.9265253330998389
# Train error after step 951: 0.792476347849532
# Test error after step 951: 0.9265253330998441
# Train error after step 952: 0.7924763478495308
# Test error after step 952: 0.9265253330998494
# Train error after step 953: 0.7924763478495295
# Test error after step 953: 0.9265253330998547
# Train error after step 954: 0.7924763478495283
# Test error after step 954: 0.9265253330998596
# Train error after step 955: 0.7924763478495267
# Test error after step 955: 0.9265253330998648
# Train error after step 956: 0.7924763478495254
# Test error after step 956: 0.9265253330998694
# Train error after step 957: 0.7924763478495244
# Test error after step 957: 0.9265253330998743
# Train error after step 958: 0.7924763478495233
# Test error after step 958: 0.9265253330998788
# Train error after step 959: 0.7924763478495219
# Test error after step 959: 0.9265253330998834
# Train error after step 960: 0.7924763478495209
# Test error after step 960: 0.9265253330998879
# Train error after step 961: 0.7924763478495198
# Test error after step 961: 0.9265253330998919
# Train error after step 962: 0.7924763478495187
# Test error after step 962: 0.926525333099896
# Train error after step 963: 0.7924763478495175
# Test error after step 963: 0.9265253330999004
# Train error after step 964: 0.7924763478495165
# Test error after step 964: 0.9265253330999044
# Train error after step 965: 0.7924763478495155
# Test error after step 965: 0.9265253330999081
# Train error after step 966: 0.7924763478495145
# Test error after step 966: 0.9265253330999121
# Train error after step 967: 0.7924763478495134
# Test error after step 967: 0.9265253330999159
# Train error after step 968: 0.7924763478495124
# Test error after step 968: 0.9265253330999196
# Train error after step 969: 0.7924763478495116
# Test error after step 969: 0.9265253330999231
# Train error after step 970: 0.7924763478495107
# Test error after step 970: 0.9265253330999268
# Train error after step 971: 0.7924763478495097
# Test error after step 971: 0.9265253330999303
# Train error after step 972: 0.792476347849509
# Test error after step 972: 0.9265253330999338
# Train error after step 973: 0.7924763478495082
# Test error after step 973: 0.926525333099937
# Train error after step 974: 0.7924763478495073
# Test error after step 974: 0.9265253330999402
# Train error after step 975: 0.7924763478495065
# Test error after step 975: 0.9265253330999434
# Train error after step 976: 0.7924763478495056
# Test error after step 976: 0.9265253330999464
# Train error after step 977: 0.7924763478495048
# Test error after step 977: 0.9265253330999493
# Train error after step 978: 0.7924763478495039
# Test error after step 978: 0.9265253330999523
# Train error after step 979: 0.7924763478495034
# Test error after step 979: 0.9265253330999553
# Train error after step 980: 0.7924763478495027
# Test error after step 980: 0.926525333099958
# Train error after step 981: 0.792476347849502
# Test error after step 981: 0.9265253330999609
# Train error after step 982: 0.7924763478495012
# Test error after step 982: 0.9265253330999635
# Train error after step 983: 0.7924763478495007
# Test error after step 983: 0.9265253330999663
# Train error after step 984: 0.7924763478495
# Test error after step 984: 0.926525333099969
# Train error after step 985: 0.792476347849499
# Test error after step 985: 0.9265253330999713
# Train error after step 986: 0.7924763478494986
# Test error after step 986: 0.926525333099974
# Train error after step 987: 0.7924763478494979
# Test error after step 987: 0.9265253330999762
# Train error after step 988: 0.7924763478494974
# Test error after step 988: 0.9265253330999789
# Train error after step 989: 0.7924763478494967
# Test error after step 989: 0.926525333099981
# Train error after step 990: 0.792476347849496
# Test error after step 990: 0.9265253330999832
# Train error after step 991: 0.7924763478494956
# Test error after step 991: 0.9265253330999853
# Train error after step 992: 0.792476347849495
# Test error after step 992: 0.9265253330999877
# Train error after step 993: 0.7924763478494944
# Test error after step 993: 0.9265253330999896
# Train error after step 994: 0.7924763478494941
# Test error after step 994: 0.9265253330999922
# Train error after step 995: 0.7924763478494933
# Test error after step 995: 0.9265253330999939
# Train error after step 996: 0.7924763478494928
# Test error after step 996: 0.926525333099996
# Train error after step 997: 0.7924763478494926
# Test error after step 997: 0.9265253330999978
# Train error after step 998: 0.792476347849492
# Test error after step 998: 0.9265253330999997
# Train error after step 999: 0.7924763478494915
# Test error after step 999: 0.9265253331000016
# Train error after step 1000: 0.7924763478494908
# Test error after step 1000: 0.9265253331000033

# %% [markdown]
# You should find that this beats the simple baselines.
# Using default SGD parameters, the alternating least squares solution here outperforms it, but by tuning SGD carefully, you should be able to get the same quality.

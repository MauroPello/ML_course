# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from test_utils import test
from typing import NamedTuple, List, Dict, Tuple
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Load the data

# %% [markdown]
# We will be working with the MovieLens dataset, containing 100k movie ratings.
# The goal is to predict the rating of a (movie, user) pair, given other ratings by this user and of this movie.

# %%
data = scipy.io.loadmat("movielens100k.mat")["ratings"]

# %%
data.shape
# Out:
# (1682, 943)

# %%
class Dataset(NamedTuple):
    """Data container with three arrays of the same length:"""

    movies: np.ndarray
    users: np.ndarray
    ratings: np.ndarray


def load_data() -> Dataset:
    """Load a sparse matrix from a matlab file and return is as a list of"""
    data = scipy.io.loadmat("movielens100k.mat")["ratings"].tocsr()
    movies, users = data.nonzero()  # indices of available ratings in the matrix
    ratings = data[movies, users].A1
    return Dataset(movies, users, ratings)


dataset = load_data()

num_users = np.max(dataset.users) + 1
num_movies = np.max(dataset.movies) + 1

print(
    f"Loaded {len(dataset.ratings)} ratings of {num_users} users for {num_movies} movies."
)
# Out:
# Loaded 100000 ratings of 943 users for 1682 movies.

# %% [markdown]
# # Plot the number of ratings per movie and user
#
# It will be too tricky to make predictions for movies and users for which too few ratings are available.
# Below we will investigate the distribution of how many ratings we have for various users and movies, to evaluate if we need to exclude some users or movies.

# %%
def count_ratings_per_movie(dataset: Dataset) -> Dict[int, int]:
    """Count the number of ratings available per movie

    Inputs:
        dataset: Dataset

    Returns:
        counts: a dictionary form movie id (int) -> count (int)

    >>> count_ratings_per_movie(Dataset(np.array([0, 0, 1]), np.array([1, 2, 1]), np.array([1.0, 2.0, 3.0])))
    {0: 2, 1: 1}
    """
    counts = {}
    for movie in dataset.movies:
        if movie not in counts.keys():
            counts[movie] = 0
        counts[movie] += 1
    return counts


def count_ratings_per_user(dataset: Dataset) -> Dict[int, int]:
    """Count the number of ratings given by a user

    Inputs:
        dataset: Dataset

    Returns:
        counts: a dictionary form user id (int) -> count (int)

    >>> count_ratings_per_user(Dataset(np.array([0, 0, 1]), np.array([1, 2, 2]), np.array([4.0, 1.0, 2.0])))
    {1: 1, 2: 2}
    """
    counts = {}
    for user in dataset.users:
        if user not in counts.keys():
            counts[user] = 0
        counts[user] += 1
    return counts

# %%
test(count_ratings_per_movie)
test(count_ratings_per_user)
# Out:
# ✅ Your `count_ratings_per_movie` passes some basic tests.
# ✅ Your `count_ratings_per_user` passes some basic tests.

# %% [markdown]
# Let's plot the results:

# %%
num_ratings_per_movie = count_ratings_per_movie(dataset)
num_ratings_per_user = count_ratings_per_user(dataset)

fig, axes = plt.subplots(ncols=2, figsize=(10, 2.5))
for ax, ratings, unit in zip(
    axes, (num_ratings_per_movie, num_ratings_per_user), ("movie", "user")
):
    ax.hist(ratings.values())
    ax.set_title(f"# Ratings per {unit} (histogram)")
    ax.set_xlabel("# Ratings")
    ax.set_ylabel("# Occurences")

# %%
print(
    "min # of movies per user = {}, \nmin # of users per movie = {}.".format(
        min(num_ratings_per_user.values()), min(num_ratings_per_movie.values())
    )
)
# Out:
# min # of movies per user = 20,
# min # of users per movie = 1.

# %% [markdown]
# # Remove movies with too few ratings
#
# As is typical for real-life data, those distributions have a very long tail. There are some movies that have only one rating. Predictions for those will be very unreliable, so we want to take them out of the dataset.

# %%
def remove_rare_movies(dataset: Dataset, min_ratings_per_movie=10) -> Dataset:
    """Filter a dataset, and keep only movies with a minimum number of reviews

    Inputs:
        dataset: Dataset
        min_cases: int, the required minimum number

    Returns:
        new dataset: Dataset

    >>> test_dataset = Dataset(np.array([0, 0, 1]), np.array([0, 1, 1]), np.array([1.0, 1.0, 1.0]))
    >>> remove_rare_movies(test_dataset, 2)
    Dataset(movies=array([0, 0]), users=array([0, 1]), ratings=array([1., 1.]))
    """
    num_ratings_per_movie = count_ratings_per_movie(dataset)

    pruned_dataset = dataset
    mask = np.zeros(dataset.movies.shape[0], dtype=np.bool)
    for i, movie in enumerate(dataset.movies):
        mask[i] = num_ratings_per_movie[movie] >= min_ratings_per_movie

    pruned_dataset = Dataset(dataset.movies[mask], dataset.users[mask], dataset.ratings[mask])
    return pruned_dataset

# %%
test(remove_rare_movies)
# Out:
# ✅ Your `remove_rare_movies` passes some basic tests.

# %%
pruned_dataset = remove_rare_movies(dataset)
print(
    f"There are {len(pruned_dataset.ratings)} ratings left after pruning the dataset."
)
# Out:
# There are 97953 ratings left after pruning the dataset.

# %% [markdown]
# # Split the data into a train and test set

# %%
def split_dataset(dataset, p_test=0.1, seed=1):
    """
    Split a dataset randomly into a train and a test part

    Inputs:
        dataset: Dataset
        p_test: float
            propability (0 < p_test < 1) for a data point to go into the test set
        seed: integer

    Returns:
        train_dataset: Dataset
        test_dataset: Dataset

    >>> split_dataset(Dataset(np.array([0, 0]), np.array([1, 0]), np.array([2.0, 1.0])), p_test=0)
    (Dataset(movies=array([0, 0]), users=array([1, 0]), ratings=array([2., 1.])), Dataset(movies=array([], dtype=int64), users=array([], dtype=int64), ratings=array([], dtype=float64)))

    >>> split_dataset(Dataset(np.array([0, 0]), np.array([1, 0]), np.array([2.0, 1.0])), p_test=1)
    (Dataset(movies=array([], dtype=int64), users=array([], dtype=int64), ratings=array([], dtype=float64)), Dataset(movies=array([0, 0]), users=array([1, 0]), ratings=array([2., 1.])))
    """
    # use this generator (https://numpy.org/doc/stable/reference/random/index.html)
    # you should use rng.uniform() once inside this function to match the automatic test case
    rng = np.random.default_rng(seed)

    test_mask = rng.uniform(size=len(dataset.ratings)) < p_test
    train_mask = ~test_mask  # invert the mask

    movies, users, ratings = dataset

    train_data = Dataset(movies[train_mask], users[train_mask], ratings[train_mask])
    test_data = Dataset(movies[test_mask], users[test_mask], ratings[test_mask])

    return train_data, test_data

# %%
test(split_dataset)
# Out:
# ✅ Your `split_dataset` passes some basic tests.

# %%
train_data, test_data = split_dataset(pruned_dataset, p_test=0.1, seed=10)
print("Number of training points:", len(train_data.ratings))
print("Number of test points:", len(test_data.ratings))
# Out:
# Number of training points: 88354
# Number of test points: 9599

# %% [markdown]
# # Visualize the dataset
# So far, our data has been represented by a list of ratings. We will look at how we can interpret these ratings in a matrix (movies x users) and plot it.

# %%
def to_matrix(dataset, num_movies, num_users):
    """
    Construct a dense matrix out of the dataset.

    Input:
        dataset: Dataset

    Output:
        matrix: np.array of floats: (# movies, # users) -> rating (float) or np.nan if unavailable

    >>> to_matrix(Dataset(np.array([1, 1, 0]), np.array([0, 1, 0]), np.array([1.0, 3.0, 2.5])), 3, 2)
    array([[2.5, nan],
           [1. , 3. ],
           [nan, nan]])
    """
    m = (
        np.zeros([num_movies, num_users]) * np.nan
    )  # We want NaNs for unavailable ratings

    for i, rating in enumerate(dataset.ratings):
        m[dataset.movies[i], dataset.users[i]] = rating
    return m

# %%
test(to_matrix)
# Out:
# ✅ Your `to_matrix` passes some basic tests.

# %% [markdown]
# Let's plot the train and test dataset

# %%
fig, axes = plt.subplots(ncols=3, figsize=(8, 3))
for ax, label, data in zip(
    axes, ("All data", "Train data", "Test data"), (dataset, train_data, test_data)
):
    im = ax.matshow(to_matrix(data, num_movies, num_users))
    ax.set_title(label)
    ax.set_xlabel("Movie")
    ax.set_ylabel("User")
fig.colorbar(im, label="Rating");

# %% [markdown]
# # Comparing predictors
#
# The goal of recommender systems is to fill in those matrices. In the remainder of this Notebook, we will implement different methods of making those predictions. Let's first develop the tools to compare them.
#
# Our prediction methods will all have the following form:

# %% [markdown]
# As an example, a predictor that recommends the same rating everywhere would look like this:

# %%
class Predictor:
    def __init__(self, train_data: Dataset):
        # This is where you can do any preparation or 'training' if necessary.
        pass

    def __call__(self, test_data: Dataset):
        """
        Make predictions for the users and movies in the test dataset
        (without looking at the ratings).

        Inputs:
            test_data: Dataset (with `n` entries)

        Output:
            predictions: np.array of floats, shape (`n`)
        """
        raise NotImplementedError()

# %% [markdown]
#  You would use a predictor like this as follows:
#
#  ```
#  p = Predictor(train_data)  # this initializes the model. This may include training.
#  predictions = p(test_data)  # this calls `__call__` and makes a prediction.
#  ```

# %%
class GlobalMeanPredictor(Predictor):
    def __init__(self, train_data: Dataset):
        self.mean = train_data.ratings.mean()

    def __call__(self, test_data: Dataset):
        """
        Always predict the mean rating from the training set

        >>> train_data = Dataset(np.array([1, 2, 3, 4]), np.array([1, 2, 3, 4]), np.array([1.0, 2.0, 2.0, 5.0]))
        >>> test_data = Dataset(np.array([1, 2, 3, 4]), np.array([2, 1, 4, 0]), np.array([4.0, 1.0, 1.0, 2.0]))
        >>> mean_predictor = GlobalMeanPredictor(train_data)
        >>> mean_predictor(test_data)
        array([2.5, 2.5, 2.5, 2.5])
        """
        return np.full_like(test_data.ratings, fill_value=self.mean)

# %%
test(GlobalMeanPredictor.__call__)
# Out:
# ✅ Your `__call__` passes some basic tests.

# %% [markdown]
# We can evaluate the predictions using Mean Squared Error:

# %%
def mse(predictions, real_ratings):
    """Compute the mean squared prediction error

    Inputs:
        predictions: np.array of floats, shape (n)
        real_ratings: np.array of floats, shape (n)

    Returns:
        mean squared error: float

    >>> mse(np.array([1., 1.2, 2.]), np.array([2., 1., 1.5]))
    0.43
    >>> mse(np.array([4., 2., 1.]), np.array([4., 3., 1.]))
    0.3333333333333333
    """
    return float(np.mean((predictions - real_ratings) ** 2))

# %%
test(mse)
# Out:
# ✅ Your `mse` passes some basic tests.

# %% [markdown]
# The error for the global mean predictor can now be computed:

# %%
predict_global_mean = GlobalMeanPredictor(train_data)

mse(predict_global_mean(test_data), test_data.ratings)
# Out:
# 1.2454544657178057

# %% [markdown]
# It is always good to include simple baselines like this one in your machine learning experimentation. We now know that we should at least beat an MSE of `1.24` on the test set.

# %% [markdown]
# ## Baselines

# %% [markdown]
# We will now gradually make the baseline predictor more complex, by differentiating between users. The idea is that some users will give higher scores on average than others.

# %% [markdown]
# ### User's mean prediction
#
# Here, to predict the score for a tuple `(movie, user)`, we will return the  average all movie ratings of the `user`.

# %%
class UserMeanPredictor(Predictor):
    def __init__(self, train_data: Dataset):
        users = np.unique(train_data.users)
        self.ratings = np.zeros([np.max(users) + 1]) * np.nan
        for user in users:
            self.ratings[user] = np.mean(train_data.ratings[train_data.users == user])


    def __call__(self, test_data: Dataset):
        """
        >>> train_data = Dataset(np.array([1, 2, 3, 4]), np.array([1, 2, 3, 4]), np.array([1.0, 2.0, 2.0, 5.0]))
        >>> test_data = Dataset(np.array([1, 2, 3, 4]), np.array([2, 1, 4, 0]), np.array([4.0, 1.0, 1.0, 2.0]))
        >>> mean_predictor = GlobalMeanPredictor(train_data)
        >>> mean_predictor(test_data)
        array([2.5, 2.5, 2.5, 2.5])
        """
        return self.ratings[test_data.users]

# %%
test(UserMeanPredictor.__call__)
# Out:
# ✅ Your `__call__` passes some basic tests.

# %% [markdown]
# Is this working better than predicting the global mean?

# %%
predict_user_mean = UserMeanPredictor(train_data)

mse(predict_user_mean(test_data), test_data.ratings)
# Out:
# 1.082106040332895

# %% [markdown]
# Q: Why would always predicting the user's mean be pretty useless in practice?
#
# Q: If you want, you can improve the predictor by falling back to the global mean in case we haven't seen any ratings of a user before (or not enough of them).

# %% [markdown]
# ### Movie's mean prediction
#
# Here, to predict the score for a tuple `(movie, user)`, we will return the  average all movie ratings of the `movie`.
#
# Under what assumption is this a good model?

# %%
class MovieMeanPredictor(Predictor):
    def __init__(self, train_data: Dataset):
        movies = np.unique(train_data.movies)
        self.ratings = np.zeros([np.max(movies) + 1]) * np.nan
        for movie in movies:
            self.ratings[movie] = np.mean(train_data.ratings[train_data.movies == movie])

    def __call__(self, test_data: Dataset):
        """
        Predict the mean rating of the movie, irrespective of the user

        >>> train_data = Dataset(np.array([0, 0, 1, 1, 2]), np.array([1, 2, 3, 4, 5]), np.array([4.0, 1.0, 1.0, 2.0, 1.0]))
        >>> test_data = Dataset(np.array([0, 1, 2, 1]), np.array([1, 2, 2, 0]), np.array([1.0, 2.0, 2.5, 5.0]))
        >>> mean_predictor = MovieMeanPredictor(train_data)
        >>> mean_predictor(test_data)
        array([2.5, 1.5, 1. , 1.5])
        """
        return self.ratings[test_data.movies]

# %%
test(MovieMeanPredictor.__call__)
# Out:
# ✅ Your `__call__` passes some basic tests.

# %%
predict_movie_mean = MovieMeanPredictor(train_data)

mse(predict_movie_mean(test_data), test_data.ratings)
# Out:
# 1.0125633530609897

# %% [markdown]
# ### Matrix Factorization
#
# With those baselines, we can implement a more realistic recommendation model that using Matrix Factorization.
#
# - To each movie $i$ in the dataset, we will assign a $d$-dimensional trainable ‘representation vector’ $\mathbf{m}_i$.
# - To each user $j$ in the dataset, we will assign a $d$-dimensional trainable ‘representation vector’ $\mathbf{u}_j$.
# - You can summarize those representations in two matrices: $\mathbf{M}$ of size `(#movies, d)`, and $\mathbf{U}$ of size `(#users, d)`.
# - The predicted score we will give for a movie $i$ and a user $j$ will be the dot product $\mathbf{m}_i \cdot \mathbf{u}_j$.
# - You can simultaneously express the predicted scores for all movies and all users as a matrix of size `(#movies, #users)` as the matrix product $\mathbf{M} \mathbf{U}^\top$. This interpretation gives the name to this model.
# - Given a training set $T$ with rating triples `(movie i, user j, rating r)`,
#   we will optimize the mean squared prediction error $\frac{1}{|T|}\sum_{(i, j, r) \in T} (\mathbf{m}_i \cdot \mathbf{u}_j - r)^2$ over the training set.

# %%
class MatrixFactorizationPredictor(Predictor):
    def __init__(self, train_data: Dataset, num_features=20, seed=1):
        # Randomly initialize features for the users and the movies from N(0, 1)

        # use this generator (https://numpy.org/doc/stable/reference/random/index.html)
        # you are expected to use rng.normal() twice in this function to match the tests, once for movies, and then once for users
        rng = np.random.default_rng(seed)

        num_movies = np.max(train_data.movies) + 1
        num_users = np.max(train_data.users) + 1
        self.movie_features = rng.normal(size=[num_movies, num_features])
        self.user_features = rng.normal(size=[num_users, num_features])

        # Normally, you should train the model here, but we will skip this
        # for now, to be able to take it step-by-step.

    def __call__(self, test_data: Dataset):
        """
        Predict the rating of a user/movie pair as the dot-product
        of representation vectors of the user and the movie.

        >>> train_data = Dataset(np.array([0, 0, 1, 1, 2]), np.array([1, 2, 3, 4, 5]), np.array([4.0, 1.0, 1.0, 2.0, 1.0]))
        >>> test_data = Dataset(np.array([0, 1, 2, 1]), np.array([1, 2, 2, 0]), np.array([1.0, 2.0, 2.5, 5.0]))
        >>> mean_predictor = MatrixFactorizationPredictor(train_data)
        >>> mean_predictor(test_data)  # the factorization is not yet optimized here
        array([ 2.62654714, -2.89866225,  0.70909287,  5.29901482])
        """
        user_features = self.user_features[test_data.users]
        movie_fetures = self.movie_features[test_data.movies]
        return (user_features * movie_fetures).sum(axis=1)

# %%
test(MatrixFactorizationPredictor.__call__)
# Out:
# ✅ Your `__call__` passes some basic tests.

# %% [markdown]
# Without training, the `MatrixFactorizationPredictor` would not perform so well:

# %%
predict_global_mean = MatrixFactorizationPredictor(train_data)

mse(predict_global_mean(test_data), test_data.ratings)
# Out:
# 34.84973825903476

# %% [markdown]
# ### Optimize the factorization using SGD
#
# One way to optimize the representation vectors for movies and users, is to sample terms from the following loss function:
#
# $$\frac{1}{|T|}\sum_{(i, j, r) \in T} (\mathbf{m}_i \cdot \mathbf{u}_j - r)^2$$
#
# and optimize the sampled $\mathbf{m}_i$ and $\mathbf{u}_j$ using a stochastic gradient descent step.
#
# To improve generalization, we will add L2 regularization (also known as `weight decay`) to this model, both for the movie representations as well as for the user representations. Because those weights are unique for each movie / user, you should also sample those stochastically. If you sample a triple `(i, j, r)`, you should minimize:
#
# $$ (\mathbf{m}_i \cdot \mathbf{u}_j - r)^2 + \lambda_\text{movie} \left\lVert\mathbf{m}_i\right\rVert^2 + \lambda_\text{user} \left\lVert\mathbf{u}_j\right\rVert^2$$
#
# You should start by computing a gradient for this term.

# %%
learning_rate = 0.02
weight_decay_movie = 0.3
weight_decay_user = 0.3

predictor = MatrixFactorizationPredictor(train_data)
rng = np.random.default_rng(0)
for epoch in range(20):
    # Shuffle the dataset
    datapoint_indices = rng.permutation(len(train_data.ratings))
    for point in datapoint_indices:
        movie = train_data.movies[point]
        user = train_data.users[point]
        rating = train_data.ratings[point]

        # Optimize the factorizations in `predictor` using an SGD
        # step based on the datapoint (movie, user, rating).
        user_features = predictor.user_features[user]
        movie_features = predictor.movie_features[movie]
        err = rating - (user_features * movie_features).sum()
        movie_features += learning_rate * (err * user_features - weight_decay_movie * movie_features)
        user_features += learning_rate * (err * movie_features - weight_decay_user * user_features)

    learning_rate *= 0.9  # decay the learning rate after each epoch

    print(
        f"Train error after epoch {epoch+1}: {mse(predictor(train_data), train_data.ratings)}"
    )
    print(
        f"Test error after epoch {epoch+1}: {mse(predictor(test_data), test_data.ratings)}"
    )
# Out:
# Train error after epoch 1: 1.1808808294056248
# Test error after epoch 1: 1.8869590314229376
# Train error after epoch 2: 0.9166156001853201
# Test error after epoch 2: 1.2705102612229386
# Train error after epoch 3: 0.9053035499844204
# Test error after epoch 3: 1.1486573296179803
# Train error after epoch 4: 0.8836613431939891
# Test error after epoch 4: 1.068041384729876
# Train error after epoch 5: 0.8824007321729037
# Test error after epoch 5: 1.035310654227497
# Train error after epoch 6: 0.8907092057445303
# Test error after epoch 6: 1.0250016856081683
# Train error after epoch 7: 0.889327119188381
# Test error after epoch 7: 1.0100841109970686
# Train error after epoch 8: 0.8943599556048897
# Test error after epoch 8: 1.0051513208467266
# Train error after epoch 9: 0.8966717673413065
# Test error after epoch 9: 1.001766602615388
# Train error after epoch 10: 0.8952963806389901
# Test error after epoch 10: 0.9926906967613117
# Train error after epoch 11: 0.8924479075693423
# Test error after epoch 11: 0.9870388059171008
# Train error after epoch 12: 0.8912534815192307
# Test error after epoch 12: 0.9830367719275612
# Train error after epoch 13: 0.8957736489802736
# Test error after epoch 13: 0.9863704296048056
# Train error after epoch 14: 0.8964603532778419
# Test error after epoch 14: 0.9849784010141678
# Train error after epoch 15: 0.8950688580459725
# Test error after epoch 15: 0.979792586053537
# Train error after epoch 16: 0.8972570310729093
# Test error after epoch 16: 0.979817198260316
# Train error after epoch 17: 0.8935859340739032
# Test error after epoch 17: 0.9765124111364518
# Train error after epoch 18: 0.8957247978855616
# Test error after epoch 18: 0.9762914961904089
# Train error after epoch 19: 0.8972484458980335
# Test error after epoch 19: 0.9769053564836304
# Train error after epoch 20: 0.8984044394145044
# Test error after epoch 20: 0.9758216763814821

# %% [markdown]
# You should expect the test error to go down below 1.0.
#
# Feel free to play with the weight decay parameters and learning rates to improve these results.

# %% [markdown]
# ### Optimize the factoriziation using Alternating Least Squares
#
# Instead of optimizing the objective
#
# $$\frac{1}{|T|}\sum_{(i, j, r) \in T} (\mathbf{m}_i \cdot \mathbf{u}_j - r)^2 + \lambda_\text{movie} \left\lVert \mathbf{M} \right\rVert^2_\text{F} + \lambda_\text{user} \left\lVert \mathbf{U} \right\rVert^2_\text{F}$$
#
# using SGD by sampling terms, we can also use ‘Alternating Least Squares’. For ALS, we make the observation that, if all users representations $\mathbf{u}_j$ are fixed, optimizing all $\mathbf{m}_i$ is a simple least squares problem. Similarly, if the movie representations $\mathbf{m}_i$ are all fixed, optimizing all $\mathbf{u}_j$ is a simple least squares problem.
#
# What we will do here, is alternate between the following steps:
# - Fix the user representations, and perfectly optimize the movie representations.
# - Fix the movie representations, and perfectly optimize the user representations.

# %%
movie_regularization = 20
user_regularization = 20
max_iterations = 1000
stop_criterion = 1e-4

predictor = MatrixFactorizationPredictor(train_data)
user_features = predictor.user_features
movie_features = predictor.movie_features
rng = np.random.default_rng(0)

prev_train_error = None

for iteration in range(max_iterations):
    # Optimize the user features
    for user in np.unique(train_data.users):
        # Update `user_features[user]` by optimizing the regularized corresponding least squares objective
        mask = train_data.users == user
        user_movies = train_data.movies[mask]
        M = movie_features[user_movies]
        r = train_data.ratings[mask]
        user_features[user] = np.linalg.solve(M.T @ M + np.eye(M.shape[1]) * user_regularization, M.T @ r)

    # Optimize the movie features using least squares
    for movie in np.unique(train_data.movies):
        # Update `movie_features[movie]` by optimizing the regularized corresponding least squares objective
        mask = train_data.movies == movie
        movie_users = train_data.users[mask]
        M = user_features[movie_users]
        r = train_data.ratings[mask]
        movie_features[movie] = np.linalg.solve(M.T @ M + np.eye(M.shape[1]) * movie_regularization, M.T @ r)

    train_error = mse(predictor(train_data), train_data.ratings)
    print(f"Train error after step {iteration+1}: {train_error}")
    print(
        f"Test error after step {iteration+1}: {mse(predictor(test_data), test_data.ratings)}"
    )

    # Stop if the training error is not going down more than 'stop_criterion'
    ####################################
    ### ___ Enter your code here ___ ###
    ####################################
# Out:
# Train error after step 1: 4.2795331256791895
# Test error after step 1: 5.102430270237264
# Train error after step 2: 1.1932472707800694
# Test error after step 2: 1.3986097947816118
# Train error after step 3: 0.9855487724785076
# Test error after step 3: 1.1496391854680805
# Train error after step 4: 0.89804499280623
# Test error after step 4: 1.0506121953125505
# Train error after step 5: 0.8574256721668729
# Test error after step 5: 1.0062031489713597
# Train error after step 6: 0.8360784488703847
# Test error after step 6: 0.9839060950439644
# Train error after step 7: 0.8234798339164902
# Test error after step 7: 0.9715267097203484
# Train error after step 8: 0.8153475190130608
# Test error after step 8: 0.9640884654623995
# Train error after step 9: 0.8097499811682943
# Test error after step 9: 0.9593523736646233
# Train error after step 10: 0.8057310417941411
# Test error after step 10: 0.9562111979413073
# Train error after step 11: 0.8027671605229695
# Test error after step 11: 0.9540680352069967
# Train error after step 12: 0.8005409707543647
# Test error after step 12: 0.9525779321358808
# Train error after step 13: 0.7988452598453144
# Test error after step 13: 0.951530105730066
# Train error after step 14: 0.79753875279775
# Test error after step 14: 0.9507892652027737
# Train error after step 15: 0.7965224320069859
# Test error after step 15: 0.9502647938319213
# Train error after step 16: 0.7957253440727186
# Test error after step 16: 0.9498940410469681
# Train error after step 17: 0.7950956924303385
# Test error after step 17: 0.9496328475703733
# Train error after step 18: 0.7945950975429754
# Test error after step 18: 0.9494497904513208
# Train error after step 19: 0.7941947734511055
# Test error after step 19: 0.9493224255224628
# Train error after step 20: 0.7938728947311223
# Test error after step 20: 0.9492347026501965
# Train error after step 21: 0.793612743659228
# Test error after step 21: 0.9491751391824841
# Train error after step 22: 0.7934013935086196
# Test error after step 22: 0.9491355164546175
# Train error after step 23: 0.7932287673722349
# Test error after step 23: 0.9491099480895256
# Train error after step 24: 0.7930869594300226
# Test error after step 24: 0.9490942149159485
# Train error after step 25: 0.7929697384142632
# Test error after step 25: 0.949085290994458
# Train error after step 26: 0.7928721777128422
# Test error after step 26: 0.9490810061254792
# Train error after step 27: 0.7927903746735434
# Test error after step 27: 0.9490798054299944
# Train error after step 28: 0.7927212342054871
# Test error after step 28: 0.949080577761404
# Train error after step 29: 0.7926622999828284
# Test error after step 29: 0.9490825328611339
# Train error after step 30: 0.7926116217608048
# Test error after step 30: 0.9490851130604149
# Train error after step 31: 0.7925676506007564
# Test error after step 31: 0.9490879295330813
# Train error after step 32: 0.7925291559272762
# Test error after step 32: 0.94909071607019
# Train error after step 33: 0.7924951597811043
# Test error after step 33: 0.9490932954244391
# Train error after step 34: 0.7924648846605308
# Test error after step 34: 0.9490955547216061
# Train error after step 35: 0.792437712114491
# Test error after step 35: 0.9490974274474024
# Train error after step 36: 0.7924131498463741
# Test error after step 36: 0.9490988802261061
# Train error after step 37: 0.7923908055568711
# Test error after step 37: 0.9490999031058623
# Train error after step 38: 0.7923703661266299
# Test error after step 38: 0.9491005024191876
# Train error after step 39: 0.7923515810352864
# Test error after step 39: 0.9491006955399953
# Train error after step 40: 0.7923342491477338
# Test error after step 40: 0.9491005070405237
# Train error after step 41: 0.7923182081832417
# Test error after step 41: 0.9490999658835557
# Train error after step 42: 0.7923033263280495
# Test error after step 42: 0.9490991033815275
# Train error after step 43: 0.7922894955653933
# Test error after step 43: 0.9490979517245602
# Train error after step 44: 0.7922766263852504
# Test error after step 44: 0.9490965429311451
# Train error after step 45: 0.7922646436047888
# Test error after step 45: 0.9490949081132098
# Train error after step 46: 0.7922534830840107
# Test error after step 46: 0.9490930769752788
# Train error after step 47: 0.7922430891628481
# Test error after step 47: 0.9490910774879934
# Train error after step 48: 0.7922334126787851
# Test error after step 48: 0.9490889356914403
# Train error after step 49: 0.7922244094500693
# Test error after step 49: 0.9490866755948683
# Train error after step 50: 0.7922160391303761
# Test error after step 50: 0.9490843191476236
# Train error after step 51: 0.792208264357653
# Test error after step 51: 0.949081886262217
# Train error after step 52: 0.7922010501336815
# Test error after step 52: 0.9490793948749675
# Train error after step 53: 0.792194363382363
# Test error after step 53: 0.9490768610330597
# Train error after step 54: 0.7921881726443073
# Test error after step 54: 0.9490742989994111
# Train error after step 55: 0.7921824478733656
# Test error after step 55: 0.9490717213687132
# Train error after step 56: 0.7921771603075398
# Test error after step 56: 0.9490691391895142
# Train error after step 57: 0.7921722823924173
# Test error after step 57: 0.9490665620884037
# Train error after step 58: 0.7921677877400736
# Test error after step 58: 0.9490639983933032
# Train error after step 59: 0.7921636511103652
# Test error after step 59: 0.9490614552536045
# Train error after step 60: 0.7921598484048282
# Test error after step 60: 0.9490589387555146
# Train error after step 61: 0.7921563566660593
# Test error after step 61: 0.949056454031446
# Train error after step 62: 0.7921531540775965
# Test error after step 62: 0.9490540053626818
# Train error after step 63: 0.7921502199610143
# Test error after step 63: 0.9490515962748677
# Train error after step 64: 0.7921475347682243
# Test error after step 64: 0.9490492296261209
# Train error after step 65: 0.7921450800679821
# Test error after step 65: 0.9490469076877508
# Train error after step 66: 0.792142838526284
# Test error after step 66: 0.9490446322177363
# Train error after step 67: 0.7921407938808616
# Test error after step 67: 0.9490424045272096
# Train error after step 68: 0.792138930910304
# Test error after step 68: 0.9490402255402844
# Train error after step 69: 0.7921372353985351
# Test error after step 69: 0.9490380958476229
# Train error after step 70: 0.792135694095486
# Test error after step 70: 0.9490360157541605
# Train error after step 71: 0.7921342946748182
# Test error after step 71: 0.9490339853214376
# Train error after step 72: 0.7921330256895424
# Test error after step 72: 0.9490320044049784
# Train error after step 73: 0.7921318765263158
# Test error after step 73: 0.9490300726871636
# Train error after step 74: 0.7921308373591247
# Test error after step 74: 0.9490281897060164
# Train error after step 75: 0.7921298991029699
# Test error after step 75: 0.9490263548803107
# Train error after step 76: 0.7921290533680826
# Test error after step 76: 0.9490245675313872
# Train error after step 77: 0.7921282924151064
# Test error after step 77: 0.9490228269020284
# Train error after step 78: 0.7921276091115969
# Test error after step 78: 0.9490211321727269
# Train error after step 79: 0.7921269968901066
# Test error after step 79: 0.9490194824756467
# Train error after step 80: 0.792126449708063
# Test error after step 80: 0.9490178769065568
# Train error after step 81: 0.792125962009576
# Test error after step 81: 0.9490163145349811
# Train error after step 82: 0.7921255286892636
# Test error after step 82: 0.949014794412793
# Train error after step 83: 0.7921251450581422
# Test error after step 83: 0.9490133155814556
# Train error after step 84: 0.7921248068115818
# Test error after step 84: 0.9490118770780813
# Train error after step 85: 0.7921245099993153
# Test error after step 85: 0.9490104779404802
# Train error after step 86: 0.7921242509974453
# Test error after step 86: 0.9490091172113253
# Train error after step 87: 0.7921240264823912
# Test error after step 87: 0.949007793941568
# Train error after step 88: 0.7921238334067007
# Test error after step 88: 0.9490065071932069
# Train error after step 89: 0.7921236689766352
# Test error after step 89: 0.9490052560415073
# Train error after step 90: 0.7921235306314436
# Test error after step 90: 0.9490040395767533
# Train error after step 91: 0.7921234160242233
# Test error after step 91: 0.9490028569056044
# Train error after step 92: 0.7921233230042742
# Test error after step 92: 0.949001707152118
# Train error after step 93: 0.792123249600854
# Test error after step 93: 0.9490005894584923
# Train error after step 94: 0.7921231940082315
# Test error after step 94: 0.9489995029855768
# Train error after step 95: 0.7921231545719546
# Test error after step 95: 0.9489984469131881
# Train error after step 96: 0.7921231297762407
# Test error after step 96: 0.9489974204402654
# Train error after step 97: 0.7921231182324074
# Test error after step 97: 0.9489964227848965
# Train error after step 98: 0.7921231186682628
# Test error after step 98: 0.9489954531842355
# Train error after step 99: 0.7921231299183814
# Test error after step 99: 0.9489945108943355
# Train error after step 100: 0.7921231509151946
# Test error after step 100: 0.9489935951899162
# Train error after step 101: 0.7921231806808299
# Test error after step 101: 0.9489927053640723
# Train error after step 102: 0.792123218319638
# Test error after step 102: 0.9489918407279473
# Train error after step 103: 0.7921232630113524
# Test error after step 103: 0.9489910006103724
# Train error after step 104: 0.7921233140048249
# Test error after step 104: 0.9489901843574857
# Train error after step 105: 0.7921233706122923
# Test error after step 105: 0.9489893913323366
# Train error after step 106: 0.7921234322041274
# Test error after step 106: 0.9489886209144783
# Train error after step 107: 0.7921234982040355
# Test error after step 107: 0.9489878724995592
# Train error after step 108: 0.792123568084653
# Test error after step 108: 0.9489871454989128
# Train error after step 109: 0.7921236413635218
# Test error after step 109: 0.9489864393391477
# Train error after step 110: 0.7921237175993988
# Test error after step 110: 0.9489857534617459
# Train error after step 111: 0.7921237963888776
# Test error after step 111: 0.948985087322664
# Train error after step 112: 0.7921238773632927
# Test error after step 112: 0.9489844403919457
# Train error after step 113: 0.792123960185884
# Test error after step 113: 0.9489838121533412
# Train error after step 114: 0.7921240445491959
# Test error after step 114: 0.948983202103936
# Train error after step 115: 0.7921241301726937
# Test error after step 115: 0.9489826097537927
# Train error after step 116: 0.7921242168005779
# Test error after step 116: 0.9489820346255993
# Train error after step 117: 0.7921243041997789
# Test error after step 117: 0.9489814762543313
# Train error after step 118: 0.7921243921581163
# Test error after step 118: 0.948980934186922
# Train error after step 119: 0.7921244804826114
# Test error after step 119: 0.9489804079819453
# Train error after step 120: 0.7921245689979352
# Test error after step 120: 0.9489798972093079
# Train error after step 121: 0.7921246575449837
# Test error after step 121: 0.9489794014499495
# Train error after step 122: 0.7921247459795716
# Test error after step 122: 0.9489789202955576
# Train error after step 123: 0.792124834171227
# Test error after step 123: 0.9489784533482846
# Train error after step 124: 0.7921249220020874
# Test error after step 124: 0.9489780002204812
# Train error after step 125: 0.7921250093658835
# Test error after step 125: 0.9489775605344338
# Train error after step 126: 0.7921250961670022
# Test error after step 126: 0.9489771339221114
# Train error after step 127: 0.7921251823196287
# Test error after step 127: 0.9489767200249207
# Train error after step 128: 0.7921252677469519
# Test error after step 128: 0.9489763184934689
# Train error after step 129: 0.7921253523804371
# Test error after step 129: 0.9489759289873326
# Train error after step 130: 0.7921254361591541
# Test error after step 130: 0.9489755511748367
# Train error after step 131: 0.7921255190291584
# Test error after step 131: 0.9489751847328336
# Train error after step 132: 0.7921256009429214
# Test error after step 132: 0.9489748293464975
# Train error after step 133: 0.7921256818588058
# Test error after step 133: 0.948974484709117
# Train error after step 134: 0.7921257617405805
# Test error after step 134: 0.9489741505218975
# Train error after step 135: 0.7921258405569754
# Test error after step 135: 0.9489738264937666
# Train error after step 136: 0.792125918281269
# Test error after step 136: 0.9489735123411889
# Train error after step 137: 0.7921259948909091
# Test error after step 137: 0.9489732077879797
# Train error after step 138: 0.7921260703671629
# Test error after step 138: 0.9489729125651292
# Train error after step 139: 0.7921261446947929
# Test error after step 139: 0.9489726264106275
# Train error after step 140: 0.7921262178617601
# Test error after step 140: 0.9489723490692961
# Train error after step 141: 0.7921262898589482
# Test error after step 141: 0.9489720802926229
# Train error after step 142: 0.7921263606799098
# Test error after step 142: 0.9489718198385992
# Train error after step 143: 0.7921264303206319
# Test error after step 143: 0.9489715674715665
# Train error after step 144: 0.7921264987793203
# Test error after step 144: 0.9489713229620593
# Train error after step 145: 0.7921265660561989
# Test error after step 145: 0.948971086086657
# Train error after step 146: 0.792126632153327
# Test error after step 146: 0.9489708566278382
# Train error after step 147: 0.7921266970744274
# Test error after step 147: 0.9489706343738372
# Train error after step 148: 0.7921267608247311
# Test error after step 148: 0.9489704191185035
# Train error after step 149: 0.7921268234108316
# Test error after step 149: 0.9489702106611678
# Train error after step 150: 0.7921268848405507
# Test error after step 150: 0.948970008806506
# Train error after step 151: 0.7921269451228169
# Test error after step 151: 0.9489698133644104
# Train error after step 152: 0.7921270042675506
# Test error after step 152: 0.9489696241498623
# Train error after step 153: 0.7921270622855582
# Test error after step 153: 0.9489694409828069
# Train error after step 154: 0.7921271191884379
# Test error after step 154: 0.9489692636880309
# Train error after step 155: 0.7921271749884888
# Test error after step 155: 0.9489690920950454
# Train error after step 156: 0.7921272296986287
# Test error after step 156: 0.9489689260379671
# Train error after step 157: 0.7921272833323194
# Test error after step 157: 0.9489687653554054
# Train error after step 158: 0.7921273359034964
# Test error after step 158: 0.9489686098903514
# Train error after step 159: 0.792127387426505
# Test error after step 159: 0.9489684594900676
# Train error after step 160: 0.7921274379160411
# Test error after step 160: 0.9489683140059826
# Train error after step 161: 0.792127487387098
# Test error after step 161: 0.9489681732935865
# Train error after step 162: 0.792127535854915
# Test error after step 162: 0.9489680372123279
# Train error after step 163: 0.7921275833349334
# Test error after step 163: 0.948967905625516
# Train error after step 164: 0.7921276298427528
# Test error after step 164: 0.9489677784002215
# Train error after step 165: 0.7921276753940947
# Test error after step 165: 0.9489676554071826
# Train error after step 166: 0.7921277200047662
# Test error after step 166: 0.9489675365207105
# Train error after step 167: 0.7921277636906264
# Test error after step 167: 0.9489674216185993
# Train error after step 168: 0.7921278064675615
# Test error after step 168: 0.9489673105820365
# Train error after step 169: 0.7921278483514522
# Test error after step 169: 0.9489672032955163
# Train error after step 170: 0.7921278893581539
# Test error after step 170: 0.9489670996467535
# Train error after step 171: 0.7921279295034723
# Test error after step 171: 0.9489669995266012
# Train error after step 172: 0.7921279688031432
# Test error after step 172: 0.9489669028289699
# Train error after step 173: 0.7921280072728157
# Test error after step 173: 0.9489668094507467
# Train error after step 174: 0.7921280449280338
# Test error after step 174: 0.948966719291719
# Train error after step 175: 0.7921280817842229
# Test error after step 175: 0.9489666322544985
# Train error after step 176: 0.7921281178566763
# Test error after step 176: 0.9489665482444459
# Train error after step 177: 0.7921281531605416
# Test error after step 177: 0.9489664671696003
# Train error after step 178: 0.7921281877108125
# Test error after step 178: 0.9489663889406077
# Train error after step 179: 0.7921282215223168
# Test error after step 179: 0.9489663134706519
# Train error after step 180: 0.7921282546097103
# Test error after step 180: 0.9489662406753878
# Train error after step 181: 0.792128286987467
# Test error after step 181: 0.9489661704728749
# Train error after step 182: 0.7921283186698741
# Test error after step 182: 0.9489661027835139
# Train error after step 183: 0.7921283496710267
# Test error after step 183: 0.9489660375299832
# Train error after step 184: 0.7921283800048208
# Test error after step 184: 0.9489659746371788
# Train error after step 185: 0.7921284096849519
# Test error after step 185: 0.9489659140321539
# Train error after step 186: 0.7921284387249096
# Test error after step 186: 0.948965855644061
# Train error after step 187: 0.7921284671379757
# Test error after step 187: 0.9489657994040945
# Train error after step 188: 0.7921284949372208
# Test error after step 188: 0.9489657452454371
# Train error after step 189: 0.7921285221355046
# Test error after step 189: 0.9489656931032034
# Train error after step 190: 0.7921285487454728
# Test error after step 190: 0.9489656429143896
# Train error after step 191: 0.7921285747795569
# Test error after step 191: 0.9489655946178195
# Train error after step 192: 0.7921286002499736
# Test error after step 192: 0.948965548154097
# Train error after step 193: 0.7921286251687251
# Test error after step 193: 0.948965503465556
# Train error after step 194: 0.7921286495475999
# Test error after step 194: 0.9489654604962127
# Train error after step 195: 0.7921286733981712
# Test error after step 195: 0.9489654191917197
# Train error after step 196: 0.7921286967318006
# Test error after step 196: 0.9489653794993201
# Train error after step 197: 0.7921287195596369
# Test error after step 197: 0.9489653413678045
# Train error after step 198: 0.7921287418926192
# Test error after step 198: 0.9489653047474674
# Train error after step 199: 0.792128763741477
# Test error after step 199: 0.9489652695900652
# Train error after step 200: 0.7921287851167328
# Test error after step 200: 0.9489652358487752
# Train error after step 201: 0.7921288060287043
# Test error after step 201: 0.948965203478158
# Train error after step 202: 0.792128826487505
# Test error after step 202: 0.9489651724341158
# Train error after step 203: 0.7921288465030483
# Test error after step 203: 0.9489651426738559
# Train error after step 204: 0.7921288660850481
# Test error after step 204: 0.9489651141558563
# Train error after step 205: 0.7921288852430226
# Test error after step 205: 0.9489650868398259
# Train error after step 206: 0.7921289039862955
# Test error after step 206: 0.9489650606866731
# Train error after step 207: 0.7921289223240003
# Test error after step 207: 0.9489650356584702
# Train error after step 208: 0.792128940265081
# Test error after step 208: 0.9489650117184214
# Train error after step 209: 0.7921289578182963
# Test error after step 209: 0.9489649888308296
# Train error after step 210: 0.7921289749922213
# Test error after step 210: 0.9489649669610666
# Train error after step 211: 0.7921289917952512
# Test error after step 211: 0.9489649460755412
# Train error after step 212: 0.792129008235604
# Test error after step 212: 0.9489649261416714
# Train error after step 213: 0.7921290243213227
# Test error after step 213: 0.9489649071278535
# Train error after step 214: 0.7921290400602788
# Test error after step 214: 0.9489648890034367
# Train error after step 215: 0.7921290554601753
# Test error after step 215: 0.9489648717386931
# Train error after step 216: 0.7921290705285488
# Test error after step 216: 0.9489648553047931
# Train error after step 217: 0.7921290852727739
# Test error after step 217: 0.9489648396737793
# Train error after step 218: 0.7921290997000641
# Test error after step 218: 0.9489648248185404
# Train error after step 219: 0.7921291138174766
# Test error after step 219: 0.9489648107127888
# Train error after step 220: 0.7921291276319142
# Test error after step 220: 0.9489647973310343
# Train error after step 221: 0.792129141150128
# Test error after step 221: 0.9489647846485632
# Train error after step 222: 0.7921291543787213
# Test error after step 222: 0.9489647726414151
# Train error after step 223: 0.792129167324151
# Test error after step 223: 0.948964761286361
# Train error after step 224: 0.7921291799927322
# Test error after step 224: 0.9489647505608818
# Train error after step 225: 0.7921291923906394
# Test error after step 225: 0.9489647404431486
# Train error after step 226: 0.79212920452391
# Test error after step 226: 0.9489647309120014
# Train error after step 227: 0.7921292163984468
# Test error after step 227: 0.948964721946931
# Train error after step 228: 0.7921292280200213
# Test error after step 228: 0.9489647135280591
# Train error after step 229: 0.7921292393942753
# Test error after step 229: 0.9489647056361201
# Train error after step 230: 0.7921292505267244
# Test error after step 230: 0.9489646982524425
# Train error after step 231: 0.792129261422761
# Test error after step 231: 0.9489646913589337
# Train error after step 232: 0.7921292720876555
# Test error after step 232: 0.9489646849380611
# Train error after step 233: 0.7921292825265601
# Test error after step 233: 0.9489646789728351
# Train error after step 234: 0.7921292927445102
# Test error after step 234: 0.9489646734467951
# Train error after step 235: 0.7921293027464283
# Test error after step 235: 0.9489646683439937
# Train error after step 236: 0.7921293125371253
# Test error after step 236: 0.9489646636489799
# Train error after step 237: 0.7921293221213028
# Test error after step 237: 0.9489646593467861
# Train error after step 238: 0.7921293315035564
# Test error after step 238: 0.9489646554229134
# Train error after step 239: 0.7921293406883767
# Test error after step 239: 0.9489646518633174
# Train error after step 240: 0.7921293496801534
# Test error after step 240: 0.9489646486543944
# Train error after step 241: 0.7921293584831756
# Test error after step 241: 0.9489646457829711
# Train error after step 242: 0.7921293671016351
# Test error after step 242: 0.9489646432362875
# Train error after step 243: 0.7921293755396286
# Test error after step 243: 0.9489646410019884
# Train error after step 244: 0.7921293838011586
# Test error after step 244: 0.9489646390681089
# Train error after step 245: 0.7921293918901372
# Test error after step 245: 0.9489646374230645
# Train error after step 246: 0.7921293998103874
# Test error after step 246: 0.9489646360556389
# Train error after step 247: 0.7921294075656443
# Test error after step 247: 0.9489646349549731
# Train error after step 248: 0.7921294151595583
# Test error after step 248: 0.9489646341105547
# Train error after step 249: 0.7921294225956962
# Test error after step 249: 0.9489646335122085
# Train error after step 250: 0.7921294298775433
# Test error after step 250: 0.9489646331500848
# Train error after step 251: 0.7921294370085056
# Test error after step 251: 0.9489646330146507
# Train error after step 252: 0.7921294439919105
# Test error after step 252: 0.9489646330966813
# Train error after step 253: 0.7921294508310109
# Test error after step 253: 0.9489646333872481
# Train error after step 254: 0.7921294575289833
# Test error after step 254: 0.9489646338777131
# Train error after step 255: 0.7921294640889336
# Test error after step 255: 0.948964634559718
# Train error after step 256: 0.792129470513895
# Test error after step 256: 0.9489646354251763
# Train error after step 257: 0.7921294768068329
# Test error after step 257: 0.9489646364662655
# Train error after step 258: 0.7921294829706435
# Test error after step 258: 0.9489646376754185
# Train error after step 259: 0.7921294890081577
# Test error after step 259: 0.9489646390453171
# Train error after step 260: 0.7921294949221416
# Test error after step 260: 0.9489646405688824
# Train error after step 261: 0.7921295007152981
# Test error after step 261: 0.9489646422392704
# Train error after step 262: 0.7921295063902676
# Test error after step 262: 0.9489646440498616
# Train error after step 263: 0.7921295119496312
# Test error after step 263: 0.9489646459942572
# Train error after step 264: 0.7921295173959109
# Test error after step 264: 0.9489646480662713
# Train error after step 265: 0.792129522731571
# Test error after step 265: 0.9489646502599233
# Train error after step 266: 0.792129527959019
# Test error after step 266: 0.948964652569433
# Train error after step 267: 0.7921295330806086
# Test error after step 267: 0.948964654989215
# Train error after step 268: 0.7921295380986384
# Test error after step 268: 0.9489646575138708
# Train error after step 269: 0.7921295430153563
# Test error after step 269: 0.9489646601381848
# Train error after step 270: 0.7921295478329574
# Test error after step 270: 0.948964662857118
# Train error after step 271: 0.7921295525535881
# Test error after step 271: 0.948964665665803
# Train error after step 272: 0.7921295571793452
# Test error after step 272: 0.948964668559538
# Train error after step 273: 0.7921295617122779
# Test error after step 273: 0.9489646715337832
# Train error after step 274: 0.7921295661543889
# Test error after step 274: 0.9489646745841533
# Train error after step 275: 0.7921295705076353
# Test error after step 275: 0.9489646777064163
# Train error after step 276: 0.7921295747739299
# Test error after step 276: 0.9489646808964851
# Train error after step 277: 0.792129578955142
# Test error after step 277: 0.9489646841504157
# Train error after step 278: 0.7921295830530988
# Test error after step 278: 0.9489646874644014
# Train error after step 279: 0.7921295870695857
# Test error after step 279: 0.9489646908347695
# Train error after step 280: 0.7921295910063475
# Test error after step 280: 0.948964694257976
# Train error after step 281: 0.7921295948650898
# Test error after step 281: 0.9489646977306032
# Train error after step 282: 0.79212959864748
# Test error after step 282: 0.9489647012493541
# Train error after step 283: 0.792129602355147
# Test error after step 283: 0.9489647048110496
# Train error after step 284: 0.7921296059896835
# Test error after step 284: 0.9489647084126245
# Train error after step 285: 0.792129609552646
# Test error after step 285: 0.9489647120511253
# Train error after step 286: 0.7921296130455562
# Test error after step 286: 0.9489647157237034
# Train error after step 287: 0.7921296164699009
# Test error after step 287: 0.948964719427616
# Train error after step 288: 0.7921296198271339
# Test error after step 288: 0.9489647231602195
# Train error after step 289: 0.7921296231186765
# Test error after step 289: 0.9489647269189687
# Train error after step 290: 0.7921296263459172
# Test error after step 290: 0.9489647307014113
# Train error after step 291: 0.7921296295102144
# Test error after step 291: 0.9489647345051876
# Train error after step 292: 0.7921296326128952
# Test error after step 292: 0.9489647383280253
# Train error after step 293: 0.7921296356552577
# Test error after step 293: 0.948964742167739
# Train error after step 294: 0.79212963863857
# Test error after step 294: 0.948964746022225
# Train error after step 295: 0.7921296415640722
# Test error after step 295: 0.948964749889461
# Train error after step 296: 0.7921296444329771
# Test error after step 296: 0.9489647537675017
# Train error after step 297: 0.7921296472464697
# Test error after step 297: 0.948964757654477
# Train error after step 298: 0.7921296500057096
# Test error after step 298: 0.9489647615485907
# Train error after step 299: 0.7921296527118296
# Test error after step 299: 0.9489647654481166
# Train error after step 300: 0.7921296553659373
# Test error after step 300: 0.9489647693513968
# Train error after step 301: 0.7921296579691162
# Test error after step 301: 0.9489647732568395
# Train error after step 302: 0.7921296605224257
# Test error after step 302: 0.9489647771629172
# Train error after step 303: 0.792129663026901
# Test error after step 303: 0.9489647810681641
# Train error after step 304: 0.7921296654835549
# Test error after step 304: 0.9489647849711743
# Train error after step 305: 0.7921296678933779
# Test error after step 305: 0.948964788870601
# Train error after step 306: 0.7921296702573379
# Test error after step 306: 0.948964792765152
# Train error after step 307: 0.7921296725763823
# Test error after step 307: 0.9489647966535902
# Train error after step 308: 0.7921296748514369
# Test error after step 308: 0.9489648005347313
# Train error after step 309: 0.7921296770834071
# Test error after step 309: 0.9489648044074415
# Train error after step 310: 0.7921296792731791
# Test error after step 310: 0.9489648082706367
# Train error after step 311: 0.7921296814216188
# Test error after step 311: 0.9489648121232793
# Train error after step 312: 0.7921296835295729
# Test error after step 312: 0.9489648159643791
# Train error after step 313: 0.7921296855978706
# Test error after step 313: 0.9489648197929895
# Train error after step 314: 0.7921296876273215
# Test error after step 314: 0.9489648236082076
# Train error after step 315: 0.7921296896187188
# Test error after step 315: 0.9489648274091711
# Train error after step 316: 0.7921296915728373
# Test error after step 316: 0.9489648311950586
# Train error after step 317: 0.7921296934904357
# Test error after step 317: 0.948964834965088
# Train error after step 318: 0.7921296953722554
# Test error after step 318: 0.9489648387185146
# Train error after step 319: 0.7921296972190225
# Test error after step 319: 0.948964842454629
# Train error after step 320: 0.7921296990314464
# Test error after step 320: 0.9489648461727583
# Train error after step 321: 0.7921297008102213
# Test error after step 321: 0.9489648498722627
# Train error after step 322: 0.7921297025560264
# Test error after step 322: 0.9489648535525358
# Train error after step 323: 0.7921297042695266
# Test error after step 323: 0.9489648572130019
# Train error after step 324: 0.7921297059513719
# Test error after step 324: 0.9489648608531173
# Train error after step 325: 0.7921297076021983
# Test error after step 325: 0.9489648644723667
# Train error after step 326: 0.792129709222628
# Test error after step 326: 0.9489648680702634
# Train error after step 327: 0.7921297108132699
# Test error after step 327: 0.9489648716463486
# Train error after step 328: 0.7921297123747199
# Test error after step 328: 0.9489648752001901
# Train error after step 329: 0.7921297139075604
# Test error after step 329: 0.9489648787313816
# Train error after step 330: 0.7921297154123625
# Test error after step 330: 0.9489648822395413
# Train error after step 331: 0.792129716889684
# Test error after step 331: 0.9489648857243108
# Train error after step 332: 0.7921297183400706
# Test error after step 332: 0.9489648891853554
# Train error after step 333: 0.7921297197640574
# Test error after step 333: 0.9489648926223623
# Train error after step 334: 0.7921297211621666
# Test error after step 334: 0.9489648960350411
# Train error after step 335: 0.7921297225349112
# Test error after step 335: 0.9489648994231208
# Train error after step 336: 0.7921297238827912
# Test error after step 336: 0.9489649027863509
# Train error after step 337: 0.7921297252062971
# Test error after step 337: 0.9489649061245002
# Train error after step 338: 0.7921297265059087
# Test error after step 338: 0.9489649094373561
# Train error after step 339: 0.7921297277820957
# Test error after step 339: 0.9489649127247236
# Train error after step 340: 0.7921297290353175
# Test error after step 340: 0.9489649159864252
# Train error after step 341: 0.7921297302660244
# Test error after step 341: 0.9489649192222996
# Train error after step 342: 0.7921297314746564
# Test error after step 342: 0.9489649224322019
# Train error after step 343: 0.7921297326616447
# Test error after step 343: 0.9489649256160023
# Train error after step 344: 0.7921297338274113
# Test error after step 344: 0.9489649287735861
# Train error after step 345: 0.792129734972369
# Test error after step 345: 0.9489649319048521
# Train error after step 346: 0.7921297360969227
# Test error after step 346: 0.9489649350097135
# Train error after step 347: 0.7921297372014678
# Test error after step 347: 0.9489649380880963
# Train error after step 348: 0.792129738286392
# Test error after step 348: 0.9489649411399397
# Train error after step 349: 0.7921297393520752
# Test error after step 349: 0.9489649441651943
# Train error after step 350: 0.7921297403988881
# Test error after step 350: 0.9489649471638232
# Train error after step 351: 0.7921297414271948
# Test error after step 351: 0.9489649501357998
# Train error after step 352: 0.7921297424373518
# Test error after step 352: 0.9489649530811093
# Train error after step 353: 0.7921297434297074
# Test error after step 353: 0.9489649559997466
# Train error after step 354: 0.7921297444046033
# Test error after step 354: 0.9489649588917167
# Train error after step 355: 0.7921297453623736
# Test error after step 355: 0.9489649617570338
# Train error after step 356: 0.7921297463033459
# Test error after step 356: 0.9489649645957222
# Train error after step 357: 0.7921297472278408
# Test error after step 357: 0.9489649674078143
# Train error after step 358: 0.7921297481361724
# Test error after step 358: 0.9489649701933505
# Train error after step 359: 0.7921297490286482
# Test error after step 359: 0.9489649729523804
# Train error after step 360: 0.7921297499055696
# Test error after step 360: 0.9489649756849601
# Train error after step 361: 0.792129750767231
# Test error after step 361: 0.9489649783911536
# Train error after step 362: 0.7921297516139217
# Test error after step 362: 0.9489649810710324
# Train error after step 363: 0.7921297524459245
# Test error after step 363: 0.948964983724674
# Train error after step 364: 0.7921297532635169
# Test error after step 364: 0.9489649863521628
# Train error after step 365: 0.7921297540669703
# Test error after step 365: 0.9489649889535889
# Train error after step 366: 0.7921297548565503
# Test error after step 366: 0.9489649915290487
# Train error after step 367: 0.7921297556325178
# Test error after step 367: 0.9489649940786444
# Train error after step 368: 0.7921297563951276
# Test error after step 368: 0.9489649966024826
# Train error after step 369: 0.7921297571446302
# Test error after step 369: 0.9489649991006759
# Train error after step 370: 0.79212975788127
# Test error after step 370: 0.9489650015733417
# Train error after step 371: 0.7921297586052876
# Test error after step 371: 0.9489650040206009
# Train error after step 372: 0.7921297593169174
# Test error after step 372: 0.9489650064425804
# Train error after step 373: 0.7921297600163903
# Test error after step 373: 0.94896500883941
# Train error after step 374: 0.7921297607039315
# Test error after step 374: 0.9489650112112239
# Train error after step 375: 0.7921297613797625
# Test error after step 375: 0.9489650135581602
# Train error after step 376: 0.7921297620440999
# Test error after step 376: 0.9489650158803598
# Train error after step 377: 0.7921297626971562
# Test error after step 377: 0.9489650181779676
# Train error after step 378: 0.7921297633391388
# Test error after step 378: 0.948965020451132
# Train error after step 379: 0.7921297639702525
# Test error after step 379: 0.9489650227000032
# Train error after step 380: 0.7921297645906963
# Test error after step 380: 0.9489650249247349
# Train error after step 381: 0.7921297652006666
# Test error after step 381: 0.9489650271254837
# Train error after step 382: 0.7921297658003547
# Test error after step 382: 0.9489650293024078
# Train error after step 383: 0.7921297663899493
# Test error after step 383: 0.948965031455669
# Train error after step 384: 0.7921297669696343
# Test error after step 384: 0.9489650335854295
# Train error after step 385: 0.7921297675395909
# Test error after step 385: 0.9489650356918549
# Train error after step 386: 0.7921297680999954
# Test error after step 386: 0.948965037775112
# Train error after step 387: 0.7921297686510219
# Test error after step 387: 0.9489650398353702
# Train error after step 388: 0.7921297691928407
# Test error after step 388: 0.9489650418727992
# Train error after step 389: 0.7921297697256184
# Test error after step 389: 0.9489650438875711
# Train error after step 390: 0.7921297702495186
# Test error after step 390: 0.9489650458798585
# Train error after step 391: 0.7921297707647011
# Test error after step 391: 0.9489650478498367
# Train error after step 392: 0.7921297712713241
# Test error after step 392: 0.9489650497976809
# Train error after step 393: 0.7921297717695405
# Test error after step 393: 0.9489650517235679
# Train error after step 394: 0.7921297722595021
# Test error after step 394: 0.948965053627674
# Train error after step 395: 0.7921297727413568
# Test error after step 395: 0.9489650555101787
# Train error after step 396: 0.7921297732152497
# Test error after step 396: 0.9489650573712604
# Train error after step 397: 0.7921297736813234
# Test error after step 397: 0.9489650592110991
# Train error after step 398: 0.7921297741397173
# Test error after step 398: 0.9489650610298743
# Train error after step 399: 0.7921297745905684
# Test error after step 399: 0.9489650628277672
# Train error after step 400: 0.7921297750340108
# Test error after step 400: 0.948965064604958
# Train error after step 401: 0.7921297754701765
# Test error after step 401: 0.9489650663616285
# Train error after step 402: 0.7921297758991941
# Test error after step 402: 0.9489650680979594
# Train error after step 403: 0.7921297763211904
# Test error after step 403: 0.9489650698141329
# Train error after step 404: 0.7921297767362898
# Test error after step 404: 0.9489650715103304
# Train error after step 405: 0.7921297771446139
# Test error after step 405: 0.9489650731867331
# Train error after step 406: 0.7921297775462822
# Test error after step 406: 0.9489650748435228
# Train error after step 407: 0.7921297779414117
# Test error after step 407: 0.9489650764808808
# Train error after step 408: 0.7921297783301173
# Test error after step 408: 0.9489650780989883
# Train error after step 409: 0.7921297787125118
# Test error after step 409: 0.9489650796980259
# Train error after step 410: 0.7921297790887059
# Test error after step 410: 0.9489650812781744
# Train error after step 411: 0.7921297794588078
# Test error after step 411: 0.9489650828396137
# Train error after step 412: 0.7921297798229237
# Test error after step 412: 0.9489650843825241
# Train error after step 413: 0.7921297801811586
# Test error after step 413: 0.9489650859070846
# Train error after step 414: 0.7921297805336146
# Test error after step 414: 0.9489650874134736
# Train error after step 415: 0.7921297808803921
# Test error after step 415: 0.9489650889018701
# Train error after step 416: 0.7921297812215895
# Test error after step 416: 0.9489650903724514
# Train error after step 417: 0.7921297815573035
# Test error after step 417: 0.9489650918253945
# Train error after step 418: 0.7921297818876294
# Test error after step 418: 0.9489650932608757
# Train error after step 419: 0.7921297822126596
# Test error after step 419: 0.9489650946790706
# Train error after step 420: 0.7921297825324862
# Test error after step 420: 0.9489650960801543
# Train error after step 421: 0.7921297828471984
# Test error after step 421: 0.9489650974643007
# Train error after step 422: 0.792129783156884
# Test error after step 422: 0.9489650988316832
# Train error after step 423: 0.7921297834616297
# Test error after step 423: 0.9489651001824744
# Train error after step 424: 0.7921297837615201
# Test error after step 424: 0.9489651015168453
# Train error after step 425: 0.7921297840566379
# Test error after step 425: 0.9489651028349672
# Train error after step 426: 0.7921297843470649
# Test error after step 426: 0.9489651041370094
# Train error after step 427: 0.7921297846328818
# Test error after step 427: 0.9489651054231409
# Train error after step 428: 0.7921297849141662
# Test error after step 428: 0.9489651066935296
# Train error after step 429: 0.7921297851909956
# Test error after step 429: 0.9489651079483418
# Train error after step 430: 0.7921297854634459
# Test error after step 430: 0.9489651091877442
# Train error after step 431: 0.7921297857315914
# Test error after step 431: 0.948965110411901
# Train error after step 432: 0.7921297859955045
# Test error after step 432: 0.948965111620976
# Train error after step 433: 0.7921297862552574
# Test error after step 433: 0.9489651128151319
# Train error after step 434: 0.7921297865109198
# Test error after step 434: 0.9489651139945299
# Train error after step 435: 0.7921297867625614
# Test error after step 435: 0.9489651151593315
# Train error after step 436: 0.7921297870102493
# Test error after step 436: 0.9489651163096949
# Train error after step 437: 0.7921297872540506
# Test error after step 437: 0.9489651174457789
# Train error after step 438: 0.7921297874940297
# Test error after step 438: 0.9489651185677407
# Train error after step 439: 0.7921297877302513
# Test error after step 439: 0.9489651196757358
# Train error after step 440: 0.7921297879627783
# Test error after step 440: 0.9489651207699195
# Train error after step 441: 0.7921297881916726
# Test error after step 441: 0.948965121850445
# Train error after step 442: 0.7921297884169942
# Test error after step 442: 0.9489651229174647
# Train error after step 443: 0.7921297886388035
# Test error after step 443: 0.9489651239711302
# Train error after step 444: 0.7921297888571583
# Test error after step 444: 0.9489651250115915
# Train error after step 445: 0.7921297890721165
# Test error after step 445: 0.948965126038997
# Train error after step 446: 0.7921297892837345
# Test error after step 446: 0.9489651270534949
# Train error after step 447: 0.7921297894920671
# Test error after step 447: 0.9489651280552313
# Train error after step 448: 0.7921297896971693
# Test error after step 448: 0.9489651290443512
# Train error after step 449: 0.7921297898990941
# Test error after step 449: 0.948965130020999
# Train error after step 450: 0.7921297900978946
# Test error after step 450: 0.9489651309853175
# Train error after step 451: 0.7921297902936216
# Test error after step 451: 0.9489651319374479
# Train error after step 452: 0.792129790486326
# Test error after step 452: 0.9489651328775307
# Train error after step 453: 0.7921297906760578
# Test error after step 453: 0.948965133805705
# Train error after step 454: 0.7921297908628652
# Test error after step 454: 0.9489651347221084
# Train error after step 455: 0.7921297910467965
# Test error after step 455: 0.948965135626878
# Train error after step 456: 0.7921297912278987
# Test error after step 456: 0.9489651365201487
# Train error after step 457: 0.7921297914062182
# Test error after step 457: 0.9489651374020548
# Train error after step 458: 0.7921297915818006
# Test error after step 458: 0.9489651382727295
# Train error after step 459: 0.7921297917546901
# Test error after step 459: 0.9489651391323041
# Train error after step 460: 0.792129791924931
# Test error after step 460: 0.9489651399809091
# Train error after step 461: 0.7921297920925662
# Test error after step 461: 0.948965140818674
# Train error after step 462: 0.7921297922576379
# Test error after step 462: 0.9489651416457265
# Train error after step 463: 0.7921297924201879
# Test error after step 463: 0.9489651424621935
# Train error after step 464: 0.7921297925802571
# Test error after step 464: 0.9489651432682006
# Train error after step 465: 0.7921297927378855
# Test error after step 465: 0.9489651440638721
# Train error after step 466: 0.7921297928931124
# Test error after step 466: 0.9489651448493316
# Train error after step 467: 0.7921297930459769
# Test error after step 467: 0.9489651456247001
# Train error after step 468: 0.7921297931965169
# Test error after step 468: 0.9489651463900989
# Train error after step 469: 0.7921297933447702
# Test error after step 469: 0.9489651471456476
# Train error after step 470: 0.7921297934907731
# Test error after step 470: 0.9489651478914644
# Train error after step 471: 0.7921297936345617
# Test error after step 471: 0.9489651486276666
# Train error after step 472: 0.7921297937761721
# Test error after step 472: 0.9489651493543694
# Train error after step 473: 0.7921297939156383
# Test error after step 473: 0.9489651500716885
# Train error after step 474: 0.7921297940529957
# Test error after step 474: 0.9489651507797373
# Train error after step 475: 0.7921297941882771
# Test error after step 475: 0.9489651514786278
# Train error after step 476: 0.7921297943215161
# Test error after step 476: 0.9489651521684717
# Train error after step 477: 0.7921297944527452
# Test error after step 477: 0.9489651528493788
# Train error after step 478: 0.7921297945819965
# Test error after step 478: 0.9489651535214586
# Train error after step 479: 0.7921297947093008
# Test error after step 479: 0.9489651541848183
# Train error after step 480: 0.7921297948346901
# Test error after step 480: 0.9489651548395647
# Train error after step 481: 0.7921297949581941
# Test error after step 481: 0.9489651554858038
# Train error after step 482: 0.7921297950798428
# Test error after step 482: 0.9489651561236396
# Train error after step 483: 0.7921297951996655
# Test error after step 483: 0.9489651567531752
# Train error after step 484: 0.792129795317691
# Test error after step 484: 0.9489651573745133
# Train error after step 485: 0.792129795433948
# Test error after step 485: 0.9489651579877549
# Train error after step 486: 0.7921297955484642
# Test error after step 486: 0.9489651585929997
# Train error after step 487: 0.7921297956612673
# Test error after step 487: 0.9489651591903472
# Train error after step 488: 0.7921297957723836
# Test error after step 488: 0.9489651597798946
# Train error after step 489: 0.7921297958818405
# Test error after step 489: 0.9489651603617388
# Train error after step 490: 0.7921297959896636
# Test error after step 490: 0.9489651609359763
# Train error after step 491: 0.7921297960958784
# Test error after step 491: 0.9489651615027007
# Train error after step 492: 0.79212979620051
# Test error after step 492: 0.948965162062006
# Train error after step 493: 0.7921297963035837
# Test error after step 493: 0.9489651626139848
# Train error after step 494: 0.7921297964051236
# Test error after step 494: 0.9489651631587283
# Train error after step 495: 0.7921297965051537
# Test error after step 495: 0.9489651636963279
# Train error after step 496: 0.7921297966036971
# Test error after step 496: 0.948965164226872
# Train error after step 497: 0.7921297967007774
# Test error after step 497: 0.9489651647504498
# Train error after step 498: 0.7921297967964178
# Test error after step 498: 0.9489651652671485
# Train error after step 499: 0.79212979689064
# Test error after step 499: 0.9489651657770547
# Train error after step 500: 0.7921297969834662
# Test error after step 500: 0.9489651662802536
# Train error after step 501: 0.7921297970749182
# Test error after step 501: 0.9489651667768301
# Train error after step 502: 0.7921297971650172
# Test error after step 502: 0.9489651672668674
# Train error after step 503: 0.7921297972537841
# Test error after step 503: 0.9489651677504484
# Train error after step 504: 0.7921297973412394
# Test error after step 504: 0.9489651682276546
# Train error after step 505: 0.7921297974274036
# Test error after step 505: 0.9489651686985671
# Train error after step 506: 0.7921297975122968
# Test error after step 506: 0.9489651691632652
# Train error after step 507: 0.792129797595938
# Test error after step 507: 0.9489651696218279
# Train error after step 508: 0.7921297976783472
# Test error after step 508: 0.9489651700743331
# Train error after step 509: 0.7921297977595428
# Test error after step 509: 0.9489651705208577
# Train error after step 510: 0.792129797839544
# Test error after step 510: 0.9489651709614783
# Train error after step 511: 0.7921297979183685
# Test error after step 511: 0.9489651713962693
# Train error after step 512: 0.792129797996035
# Test error after step 512: 0.9489651718253063
# Train error after step 513: 0.7921297980725606
# Test error after step 513: 0.9489651722486616
# Train error after step 514: 0.7921297981479632
# Test error after step 514: 0.9489651726664083
# Train error after step 515: 0.7921297982222599
# Test error after step 515: 0.9489651730786182
# Train error after step 516: 0.7921297982954677
# Test error after step 516: 0.9489651734853624
# Train error after step 517: 0.7921297983676032
# Test error after step 517: 0.9489651738867103
# Train error after step 518: 0.7921297984386826
# Test error after step 518: 0.9489651742827314
# Train error after step 519: 0.7921297985087218
# Test error after step 519: 0.9489651746734942
# Train error after step 520: 0.7921297985777372
# ...
# Train error after step 829: 0.7921298032887463
# Test error after step 829: 0.9489652028286405
# Train error after step 830: 0.7921298032896178
# Test error after step 830: 0.94896520283412
# Train error after step 831: 0.7921298032904771
# Test error after step 831: 0.9489652028395239
# Train error after step 832: 0.7921298032913247
# Test error after step 832: 0.948965202844854
# Train error after step 833: 0.7921298032921607
# Test error after step 833: 0.9489652028501104
# Train error after step 834: 0.792129803292985
# Test error after step 834: 0.9489652028552948
# Train error after step 835: 0.7921298032937979
# Test error after step 835: 0.9489652028604079
# Train error after step 836: 0.7921298032945997
# Test error after step 836: 0.9489652028654508
# Train error after step 837: 0.7921298032953904
# Test error after step 837: 0.9489652028704244
# Train error after step 838: 0.7921298032961701
# Test error after step 838: 0.9489652028753299
# Train error after step 839: 0.7921298032969393
# Test error after step 839: 0.9489652028801678
# Train error after step 840: 0.7921298032976977
# Test error after step 840: 0.948965202884939
# Train error after step 841: 0.792129803298446
# Test error after step 841: 0.9489652028896448
# Train error after step 842: 0.7921298032991838
# Test error after step 842: 0.9489652028942861
# Train error after step 843: 0.7921298032999111
# Test error after step 843: 0.9489652028988637
# Train error after step 844: 0.7921298033006285
# Test error after step 844: 0.948965202903378
# Train error after step 845: 0.7921298033013364
# Test error after step 845: 0.9489652029078305
# Train error after step 846: 0.7921298033020343
# Test error after step 846: 0.9489652029122219
# Train error after step 847: 0.7921298033027225
# Test error after step 847: 0.9489652029165528
# Train error after step 848: 0.7921298033034014
# Test error after step 848: 0.9489652029208243
# Train error after step 849: 0.7921298033040708
# Test error after step 849: 0.9489652029250369
# Train error after step 850: 0.792129803304731
# Test error after step 850: 0.9489652029291918
# Train error after step 851: 0.7921298033053824
# Test error after step 851: 0.9489652029332899
# Train error after step 852: 0.7921298033060246
# Test error after step 852: 0.9489652029373313
# Train error after step 853: 0.7921298033066578
# Test error after step 853: 0.9489652029413173
# Train error after step 854: 0.7921298033072828
# Test error after step 854: 0.9489652029452486
# Train error after step 855: 0.7921298033078986
# Test error after step 855: 0.9489652029491257
# Train error after step 856: 0.7921298033085061
# Test error after step 856: 0.9489652029529495
# Train error after step 857: 0.7921298033091052
# Test error after step 857: 0.9489652029567207
# Train error after step 858: 0.7921298033096961
# Test error after step 858: 0.9489652029604402
# Train error after step 859: 0.7921298033102789
# Test error after step 859: 0.9489652029641085
# Train error after step 860: 0.7921298033108536
# Test error after step 860: 0.9489652029677264
# Train error after step 861: 0.7921298033114205
# Test error after step 861: 0.9489652029712948
# Train error after step 862: 0.7921298033119795
# Test error after step 862: 0.948965202974814
# Train error after step 863: 0.7921298033125309
# Test error after step 863: 0.948965202978285
# Train error after step 864: 0.7921298033130746
# Test error after step 864: 0.948965202981708
# Train error after step 865: 0.792129803313611
# Test error after step 865: 0.9489652029850842
# Train error after step 866: 0.7921298033141397
# Test error after step 866: 0.9489652029884139
# Train error after step 867: 0.7921298033146615
# Test error after step 867: 0.9489652029916981
# Train error after step 868: 0.7921298033151757
# Test error after step 868: 0.9489652029949366
# Train error after step 869: 0.7921298033156832
# Test error after step 869: 0.9489652029981309
# Train error after step 870: 0.7921298033161834
# Test error after step 870: 0.9489652030012813
# Train error after step 871: 0.7921298033166767
# Test error after step 871: 0.9489652030043886
# Train error after step 872: 0.7921298033171636
# Test error after step 872: 0.9489652030074529
# Train error after step 873: 0.7921298033176434
# Test error after step 873: 0.9489652030104752
# Train error after step 874: 0.7921298033181168
# Test error after step 874: 0.9489652030134558
# Train error after step 875: 0.7921298033185836
# Test error after step 875: 0.9489652030163956
# Train error after step 876: 0.7921298033190441
# Test error after step 876: 0.9489652030192953
# Train error after step 877: 0.7921298033194981
# Test error after step 877: 0.9489652030221545
# Train error after step 878: 0.7921298033199459
# Test error after step 878: 0.9489652030249748
# Train error after step 879: 0.7921298033203874
# Test error after step 879: 0.9489652030277564
# Train error after step 880: 0.7921298033208233
# Test error after step 880: 0.9489652030304996
# Train error after step 881: 0.7921298033212528
# Test error after step 881: 0.9489652030332053
# Train error after step 882: 0.7921298033216764
# Test error after step 882: 0.9489652030358736
# Train error after step 883: 0.7921298033220943
# Test error after step 883: 0.9489652030385052
# Train error after step 884: 0.7921298033225062
# Test error after step 884: 0.9489652030411009
# Train error after step 885: 0.7921298033229125
# Test error after step 885: 0.9489652030436606
# Train error after step 886: 0.7921298033233134
# Test error after step 886: 0.9489652030461855
# Train error after step 887: 0.7921298033237086
# Test error after step 887: 0.9489652030486755
# Train error after step 888: 0.7921298033240987
# Test error after step 888: 0.9489652030511312
# Train error after step 889: 0.7921298033244829
# Test error after step 889: 0.9489652030535531
# Train error after step 890: 0.792129803324862
# Test error after step 890: 0.9489652030559418
# Train error after step 891: 0.7921298033252362
# Test error after step 891: 0.9489652030582978
# Train error after step 892: 0.7921298033256051
# Test error after step 892: 0.948965203060621
# Train error after step 893: 0.7921298033259686
# Test error after step 893: 0.9489652030629127
# Train error after step 894: 0.7921298033263275
# Test error after step 894: 0.9489652030651727
# Train error after step 895: 0.7921298033266811
# Test error after step 895: 0.9489652030674016
# Train error after step 896: 0.7921298033270301
# Test error after step 896: 0.9489652030696
# Train error after step 897: 0.7921298033273744
# Test error after step 897: 0.9489652030717682
# Train error after step 898: 0.7921298033277138
# Test error after step 898: 0.9489652030739065
# Train error after step 899: 0.7921298033280485
# Test error after step 899: 0.9489652030760155
# Train error after step 900: 0.7921298033283786
# Test error after step 900: 0.9489652030780954
# Train error after step 901: 0.792129803328704
# Test error after step 901: 0.9489652030801469
# Train error after step 902: 0.7921298033290252
# Test error after step 902: 0.94896520308217
# Train error after step 903: 0.7921298033293419
# Test error after step 903: 0.9489652030841654
# Train error after step 904: 0.7921298033296541
# Test error after step 904: 0.9489652030861332
# Train error after step 905: 0.7921298033299621
# Test error after step 905: 0.9489652030880742
# Train error after step 906: 0.7921298033302657
# Test error after step 906: 0.9489652030899883
# Train error after step 907: 0.7921298033305653
# Test error after step 907: 0.9489652030918763
# Train error after step 908: 0.7921298033308609
# Test error after step 908: 0.9489652030937381
# Train error after step 909: 0.7921298033311522
# Test error after step 909: 0.9489652030955743
# Train error after step 910: 0.7921298033314397
# Test error after step 910: 0.9489652030973859
# Train error after step 911: 0.7921298033317232
# Test error after step 911: 0.9489652030991719
# Train error after step 912: 0.7921298033320026
# Test error after step 912: 0.9489652031009335
# Train error after step 913: 0.7921298033322781
# Test error after step 913: 0.948965203102671
# Train error after step 914: 0.7921298033325502
# Test error after step 914: 0.9489652031043843
# Train error after step 915: 0.7921298033328182
# Test error after step 915: 0.9489652031060744
# Train error after step 916: 0.792129803333083
# Test error after step 916: 0.9489652031077412
# Train error after step 917: 0.7921298033333437
# Test error after step 917: 0.9489652031093849
# Train error after step 918: 0.7921298033336008
# Test error after step 918: 0.9489652031110061
# Train error after step 919: 0.7921298033338546
# Test error after step 919: 0.948965203112605
# Train error after step 920: 0.7921298033341049
# Test error after step 920: 0.9489652031141822
# Train error after step 921: 0.7921298033343516
# Test error after step 921: 0.9489652031157374
# Train error after step 922: 0.7921298033345948
# Test error after step 922: 0.9489652031172714
# Train error after step 923: 0.792129803334835
# Test error after step 923: 0.9489652031187842
# Train error after step 924: 0.7921298033350714
# Test error after step 924: 0.9489652031202763
# Train error after step 925: 0.7921298033353048
# Test error after step 925: 0.9489652031217477
# Train error after step 926: 0.7921298033355351
# Test error after step 926: 0.9489652031231991
# Train error after step 927: 0.792129803335762
# Test error after step 927: 0.9489652031246304
# Train error after step 928: 0.7921298033359861
# Test error after step 928: 0.9489652031260422
# Train error after step 929: 0.7921298033362072
# Test error after step 929: 0.9489652031274344
# Train error after step 930: 0.7921298033364248
# Test error after step 930: 0.9489652031288075
# Train error after step 931: 0.7921298033366395
# Test error after step 931: 0.9489652031301619
# Train error after step 932: 0.7921298033368516
# Test error after step 932: 0.9489652031314973
# Train error after step 933: 0.7921298033370604
# Test error after step 933: 0.9489652031328147
# Train error after step 934: 0.7921298033372666
# Test error after step 934: 0.948965203134114
# Train error after step 935: 0.79212980333747
# Test error after step 935: 0.9489652031353953
# Train error after step 936: 0.7921298033376702
# Test error after step 936: 0.9489652031366589
# Train error after step 937: 0.7921298033378682
# Test error after step 937: 0.9489652031379054
# Train error after step 938: 0.792129803338063
# Test error after step 938: 0.9489652031391346
# Train error after step 939: 0.7921298033382551
# Test error after step 939: 0.9489652031403469
# Train error after step 940: 0.7921298033384448
# Test error after step 940: 0.9489652031415425
# Train error after step 941: 0.7921298033386319
# Test error after step 941: 0.9489652031427217
# Train error after step 942: 0.7921298033388164
# Test error after step 942: 0.9489652031438844
# Train error after step 943: 0.7921298033389984
# Test error after step 943: 0.9489652031450315
# Train error after step 944: 0.7921298033391776
# Test error after step 944: 0.9489652031461628
# Train error after step 945: 0.7921298033393548
# Test error after step 945: 0.9489652031472784
# Train error after step 946: 0.7921298033395294
# Test error after step 946: 0.9489652031483786
# Train error after step 947: 0.7921298033397013
# Test error after step 947: 0.9489652031494639
# Train error after step 948: 0.7921298033398712
# Test error after step 948: 0.9489652031505341
# Train error after step 949: 0.7921298033400385
# Test error after step 949: 0.9489652031515896
# Train error after step 950: 0.7921298033402037
# Test error after step 950: 0.9489652031526308
# Train error after step 951: 0.7921298033403664
# Test error after step 951: 0.9489652031536576
# Train error after step 952: 0.792129803340527
# Test error after step 952: 0.9489652031546701
# Train error after step 953: 0.7921298033406854
# Test error after step 953: 0.948965203155669
# Train error after step 954: 0.7921298033408414
# Test error after step 954: 0.9489652031566538
# Train error after step 955: 0.7921298033409954
# Test error after step 955: 0.9489652031576251
# Train error after step 956: 0.7921298033411477
# Test error after step 956: 0.9489652031585837
# Train error after step 957: 0.7921298033412972
# Test error after step 957: 0.9489652031595283
# Train error after step 958: 0.7921298033414453
# Test error after step 958: 0.9489652031604603
# Train error after step 959: 0.7921298033415911
# Test error after step 959: 0.9489652031613793
# Train error after step 960: 0.7921298033417348
# Test error after step 960: 0.9489652031622858
# Train error after step 961: 0.7921298033418765
# Test error after step 961: 0.9489652031631799
# Train error after step 962: 0.7921298033420162
# Test error after step 962: 0.9489652031640616
# Train error after step 963: 0.7921298033421541
# Test error after step 963: 0.9489652031649315
# Train error after step 964: 0.7921298033422901
# Test error after step 964: 0.9489652031657889
# Train error after step 965: 0.7921298033424243
# Test error after step 965: 0.9489652031666347
# Train error after step 966: 0.7921298033425568
# Test error after step 966: 0.948965203167469
# Train error after step 967: 0.792129803342687
# Test error after step 967: 0.9489652031682918
# Train error after step 968: 0.7921298033428157
# Test error after step 968: 0.9489652031691033
# Train error after step 969: 0.7921298033429427
# Test error after step 969: 0.9489652031699033
# Train error after step 970: 0.7921298033430676
# Test error after step 970: 0.9489652031706928
# Train error after step 971: 0.7921298033431912
# Test error after step 971: 0.9489652031714711
# Train error after step 972: 0.7921298033433128
# Test error after step 972: 0.9489652031722386
# Train error after step 973: 0.792129803343433
# Test error after step 973: 0.9489652031729959
# Train error after step 974: 0.7921298033435515
# Test error after step 974: 0.9489652031737429
# Train error after step 975: 0.7921298033436681
# Test error after step 975: 0.9489652031744793
# Train error after step 976: 0.7921298033437835
# Test error after step 976: 0.9489652031752058
# Train error after step 977: 0.7921298033438969
# Test error after step 977: 0.9489652031759219
# Train error after step 978: 0.792129803344009
# Test error after step 978: 0.9489652031766286
# Train error after step 979: 0.7921298033441194
# Test error after step 979: 0.9489652031773254
# Train error after step 980: 0.7921298033442284
# Test error after step 980: 0.9489652031780127
# Train error after step 981: 0.792129803344336
# Test error after step 981: 0.9489652031786903
# Train error after step 982: 0.7921298033444419
# Test error after step 982: 0.9489652031793588
# Train error after step 983: 0.7921298033445465
# Test error after step 983: 0.9489652031800181
# Train error after step 984: 0.7921298033446492
# Test error after step 984: 0.9489652031806682
# Train error after step 985: 0.7921298033447512
# Test error after step 985: 0.9489652031813095
# Train error after step 986: 0.7921298033448515
# Test error after step 986: 0.9489652031819423
# Train error after step 987: 0.7921298033449503
# Test error after step 987: 0.9489652031825659
# Train error after step 988: 0.7921298033450478
# Test error after step 988: 0.948965203183181
# Train error after step 989: 0.7921298033451442
# Test error after step 989: 0.9489652031837879
# Train error after step 990: 0.7921298033452391
# Test error after step 990: 0.9489652031843863
# Train error after step 991: 0.7921298033453325
# Test error after step 991: 0.9489652031849763
# Train error after step 992: 0.7921298033454247
# Test error after step 992: 0.9489652031855584
# Train error after step 993: 0.7921298033455156
# Test error after step 993: 0.9489652031861324
# Train error after step 994: 0.7921298033456057
# Test error after step 994: 0.9489652031866986
# Train error after step 995: 0.7921298033456939
# Test error after step 995: 0.9489652031872571
# Train error after step 996: 0.7921298033457811
# Test error after step 996: 0.9489652031878076
# Train error after step 997: 0.7921298033458676
# Test error after step 997: 0.9489652031883508
# Train error after step 998: 0.7921298033459524
# Test error after step 998: 0.9489652031888864
# Train error after step 999: 0.792129803346036
# Test error after step 999: 0.9489652031894148
# Train error after step 1000: 0.7921298033461186
# Test error after step 1000: 0.9489652031899355

# %% [markdown]
# You should find that this beats the simple baselines.
# Using default SGD parameters, the alternating least squares solution here outperforms it, but by tuning SGD carefully, you should be able to get the same quality.
